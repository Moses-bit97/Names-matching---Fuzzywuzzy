# %%
#importing libraries
import numpy as np
import pandas as pd
import re
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('mdc-1.csv')
data.tail(10) #display last 10 rows in data
# Out:
#              id       activity_id  \
# 3426  3,192,802        MDC1-10606
# 3427  3,194,335  MDC1.C1.Cx3020.1
# 3428  3,192,808        MDC1-10607
# 3429  3,192,809        MDC1-10608
# 3430  3,192,810        MDC1-10609
# 3431  3,192,812        MDC1-10610
# 3432  3,192,818        MDC1-10611
# 3433  3,192,813        MDC1-10612
# 3434  3,192,814        MDC1-10613
# 3435  3,192,816        MDC1-10614
#
#                                                    name
# 3426  COLO-2 Cell-4 UPS PNL01 Compass issues Prevent...
# 3427              Additional Go-Back loadbanking (ASCO)
# 3428  6.1-98 Admin/COLO-1 ASCO EPMS Connectivity Issues
# 3429  6.1-88  Admin/ COLO-1 MER/ADMIN UPS L3 Testing...
# 3430   6.1-106 COLO-1 Cell-2 UPS01 Power module failure
# 3431  COLO-2 Cell-1 Open Issues preventing Yellow ta...
# 3432  COLO-2 Cell-2 Open Issues preventing Yellow ta...
# 3433  COLO-2 Cell-3 Open Issues preventing Yellow ta...
# 3434  COLO-2 Cell-4 Open Issues preventing Yellow ta...
# 3435          COLO-3 Delay in SE uploading QC Checkilst

# %%
### Divide data set into 1-word names and multiword names
### All 1-word rows are clusters.

# %%
data['lower_case_names'] = data['name'].str.lower() #change make column a lowercase

# %%
data.head()
# Out:
#           id   activity_id                                           name  \
# 0  3,191,380    MDC1-UP#13  MDC1 Master Update #13- DD 8.31.2021Submitted
# 1  3,191,381  MDC1-UP#13.1                 Executive Summary / Milestones
# 2  3,192,817  MDC1-UP#13.5                                   Construction
# 3  3,191,388  MDC1-UP#13.2                           Construction Summary
# 4  3,191,673  MDC1-UP#13.4                                Preconstruction
#
#                                 lower_case_names
# 0  mdc1 master update #13- dd 8.31.2021submitted
# 1                 executive summary / milestones
# 2                                   construction
# 3                           construction summary
# 4                                preconstruction

# %%
##check for 1-word in table

# %%
data['is_one_word_name'] = data['lower_case_names'].map(lambda n: len(n.split(" ")) == 1)

# %%
data.head()
# Out:
#           id   activity_id                                           name  \
# 0  3,191,380    MDC1-UP#13  MDC1 Master Update #13- DD 8.31.2021Submitted
# 1  3,191,381  MDC1-UP#13.1                 Executive Summary / Milestones
# 2  3,192,817  MDC1-UP#13.5                                   Construction
# 3  3,191,388  MDC1-UP#13.2                           Construction Summary
# 4  3,191,673  MDC1-UP#13.4                                Preconstruction
#
#                                 lower_case_names  is_one_word_name
# 0  mdc1 master update #13- dd 8.31.2021submitted             False
# 1                 executive summary / milestones             False
# 2                                   construction              True
# 3                           construction summary             False
# 4                                preconstruction              True

# %%
data_1_word = data[data.is_one_word_name == True]

# %%
data_1_word.head()
# Out:
#            id     activity_id             name lower_case_names  \
# 2   3,192,817    MDC1-UP#13.5     Construction     construction
# 4   3,191,673    MDC1-UP#13.4  Preconstruction  preconstruction
# 6   3,192,002    MDC1-UP#13.6            DELAY            delay
# 9   3,192,819  MDC1-UP#13.5.1             Site             site
# 13  3,191,600  MDC1-UP#13.3.1          General          general
#
#     is_one_word_name
# 2               True
# 4               True
# 6               True
# 9               True
# 13              True

# %%
data_1_word.shape #shape of 1-word
# Out:
# (419, 5)

# %%
data_multiword = data[data.is_one_word_name == False]

# %%
data_multiword.shape #shape of multiple words
# Out:
# (3017, 5)

# %%
data.shape
# Out:
# (3436, 5)

# %%
419/3436 #checking ratio of 1-word to multiple words
# Out:
# 0.12194412107101281

# %%
### Second Stage
##  Create a dictionary of all one-word names mapped to a list
##  Iterate over each

# %%
def make_cluser_dictionary(df):
    clusters = dict()
    for i, row in df.iterrows():
        name = row['lower_case_names']
        clusters[name] = []
    return clusters

# %%
cl = make_cluser_dictionary(data_1_word)

# %%
cl.keys()
# Out:
# dict_keys(['construction', 'preconstruction', 'delay', 'site', 'general', 'admin/colo1', 'fitout', 'commissioning', 'colo-2', 'colo-3', 'colo-4', 'update#4', 'punchlist', 'update#6', 'update#7', 'update#8', 'update#10', 'update#12', 'admin', 'colo-1', 'admin/colo-1', 'structure', 'l2', 'l3', 'mer', 'drb#1', 'term', 'ahu', 'upm', 'generator', 'pdu', 'procurement', 'se', 'foundations', 'roof', 'partitions', 'finishes', 'specialities', 'electrical', 'plumbing', 'mechanical', 'vaults', 'cell-1', 'cell-3', 'cell-2', 'cell-4', 'jaz', 'fiber', 'building', 'west', 'east', 'mobilization', '`', 'rfi#432'])

# %%
cl  #display 1-word dictionaries
# Out:
# {'construction': [],
#  'preconstruction': [],
#  'delay': [],
#  'site': [],
#  'general': [],
#  'admin/colo1': [],
#  'fitout': [],
#  'commissioning': [],
#  'colo-2': [],
#  'colo-3': [],
#  'colo-4': [],
#  'update#4': [],
#  'punchlist': [],
#  'update#6': [],
#  'update#7': [],
#  'update#8': [],
#  'update#10': [],
#  'update#12': [],
#  'admin': [],
#  'colo-1': [],
#  'admin/colo-1': [],
#  'structure': [],
#  'l2': [],
#  'l3': [],
#  'mer': [],
#  'drb#1': [],
#  'term': [],
#  'ahu': [],
#  'upm': [],
#  'generator': [],
#  'pdu': [],
#  'procurement': [],
#  'se': [],
#  'foundations': [],
#  'roof': [],
#  'partitions': [],
#  'finishes': [],
#  'specialities': [],
#  'electrical': [],
#  'plumbing': [],
#  'mechanical': [],
#  'vaults': [],
#  'cell-1': [],
#  'cell-3': [],
#  'cell-2': [],
#  'cell-4': [],
#  'jaz': [],
#  'fiber': [],
#  'building': [],
#  'west': [],
#  'east': [],
#  'mobilization': [],
#  '`': [],
#  'rfi#432': []}

# %%
#compares key and extracts multiwords as values
def build_clusters(df_source, df_clusters):
    clusters = make_cluser_dictionary(df_clusters)
    for cluster_key in clusters.keys():
        for i,j in df_source.iterrows():
#             print(i,j['lower_case_names'])
            name = j['lower_case_names']
            
            if cluster_key in name:
                clusters[cluster_key].append(name)
        ## iterate over df_source rows
    return clusters

# %%
name_clusters = build_clusters(data_multiword, data_1_word)

# %%
name_clusters
# Out:
# {'construction': ['construction summary',
#   'bas prefunctional testing on construction server',
#   'bas prefunctional testing on construction server',
#   'bas prefunctional testing on construction server',
#   'bas prefunctional testing on construction server',
#   'jaz riser support drb#1 procurement/ jaz foundations/construction',
#   'construction server- colo-1',
#   'construction server- colo-2',
#   'construction server- colo-3',
#   'construction server- colo-4',
#   'all construction activities -safety standown due to admin gen unplanned energization'],
#  'preconstruction': [],
#  'delay': ['executed delays (co-66)',
#   'pending delays',
#   'delay #1 late submittal approval',
#   'delay #3 fluid cooler',
#   'delay #2 late upm deliveries',
#   'delay #4 drb#2',
#   'delay #5 water treatment skids delay',
#   'delay #6 drb#3',
#   'delay #7- force majeure shutdown -hazardous air quality index',
#   'delay #8-underground utilities impacted by overhead power lines',
#   'delay #9 mer delivery delay',
#   'delay#10 covid procurement delay',
#   'delay#11 mwh02- telecom vault tie-in msow delay',
#   'delay#12 late ums delivery delay',
#   'delay#13 gen delivery delay',
#   'delay#14 weather',
#   'delay#15 wa state l&i mer onsite inspection delay due to covid-19',
#   'delay#16 nopc-8 se - missing mer raceways',
#   'delay#17 nopc-9 se - mer roxtec raceway fixes',
#   'delay#18 nopc-10 se - mer flex conduit code & specification violation',
#   'delay#19 nopc-11 failed starline busway hangers',
#   'delay#20 admin gen missing bussing',
#   'delay#21 nopc-12 se field install mer batteries delay',
#   'delay#22 nopc-13 february 2021 cx constraints',
#   'delay#23 nopc-14 mer set safety delay',
#   'delay#24 nopc-15 gen cable bus opening dimension bust',
#   'delay#25 veca safety standown due to admin gen unplanned enegization',
#   'delay#26 field modification of tray above msb',
#   'delay#28 nopc-17 march 2021 cx constraints',
#   'delay#27 nopc-16 missing wireway in colos 2-4 generators',
#   'delay#31 nopc-20 april 2021 cx constraints',
#   'delay#29 nopc-18 msb01 pdu feeder breaker safety space constraint',
#   'delay#30 nopc-19 covid-19 electrician quarantine constraint',
#   'delay#32 missing admin arc flash labels (rfi-520)',
#   'delay#33 nopc-22 may 2021 cx constraints',
#   'delay#34 site stand-down (diversity training)',
#   'delay#35- nopc-23 - rfi548- mer-contractor g battery disconnect modifications',
#   'delay#36- nopc-21 colo-3 & 4 mer cable bus access space constraint',
#   'delay#37- nopc-24 colo-3 mer raceway constraints',
#   'delay#38 nopc-25 colo-4 mer raceway constraints',
#   'delay#39 nopc-26 july cx constraints',
#   'delay#40  contractor g pnl01 issues',
#   'delay #41 nopc-27 aug  cx constraints',
#   'delay#22.1 contractor a february 2021 cx constraints',
#   'delay#22.2 contractor d february 2021 cx constraints',
#   'delay#22.3 contractor c february 2021 cx constraints',
#   'delay#22.4 contractor b february 2021 cx constraints',
#   'delay#28.1 contractor a',
#   'delay#28.2 contractor d',
#   'delay#28.3 contractor c february',
#   'delay#28.4 contractor b',
#   'delay#31.1 contractor a',
#   'delay#31.2 contractor d',
#   'delay#31.3 contractor c february',
#   'delay#31.4 contractor b',
#   'delay#31.5 contractor e',
#   'delay#31.6 bac',
#   'delay#33.1 contractor a',
#   'delay#33.2 contractor d',
#   'delay#33.3 contractor c february',
#   'delay#33.4 contractor b',
#   'delay#33.5 contractor e',
#   'delay#33.6 bac',
#   'delay#39.1 contractor a',
#   'delay#39.2 contractor f',
#   'delay#39.3 contractor a1',
#   'delay#39.1 contractor a',
#   'delay#39.2 contractor f',
#   'delay#39.3 contractor a1',
#   'weather (5 days) - 3 remaining check delay #14 for updates',
#   'weather (5 days) - 3 remaining check delay #14 for updates',
#   'weather (5 days) - 3 remaining check delay #14 for updates',
#   'weather (5 days) - 0 remaining check delay #14 for updates',
#   'delay in upm delivery (duration = colo1 cell-1 psr (9/19) to msft delivery)',
#   'delay in colo-1- cell-1 mer delivery (duration = colo1 cell-1 psr(11/6/20) to msft delivery)',
#   'delay in upm delivery (duration = colo1 cell-2 psr(10/13) to msft delivery)',
#   'delay in upm delivery (duration = colo1 cell-3 psr(9/28) to msft delivery)',
#   'delay in upm delivery (duration = colo1 cell-4 psr (10/28) to msft delivery)',
#   'delay in colo-1- cell-2 mer delivery (duration = colo1 cell-2 psr(11/13/20) to msft delivery)',
#   'delay in colo-1- cell-3 mer delivery (duration = colo1 cell-3 psr(11/20/20) to msft delivery)',
#   'delay in colo-2- cell-1 mer delivery (duration = colo1 cell-1 psr(12/15/20) to msft delivery)',
#   'delay in colo-2- cell-2 mer delivery (duration = colo 2 cell-2 psr(12/22/20) to msft delivery)',
#   'delay in colo-2- cell-3 mer delivery (duration = colo 2- cell-3 psr(12/28/20) to msft delivery)',
#   'delay in colo-3- cell-1 mer delivery (duration = colo-3 cell-1 psr(1/29/21) to msft delivery)',
#   'delay in colo-3- cell-2 mer delivery (duration = colo-3 cell-2 psr(2/5/21) to msft delivery)',
#   'delay in colo-3 cell-3 mer delivery (duration = colo-3 cell-3 psr(2/12/21) to msft delivery)',
#   'delay in colo-4- cell-1 mer delivery (duration= colo-4 cell-1 psr(3/12/21) to msft delivery)',
#   'delay in colo-4- cell-2 mer delivery (duration = colo-4 cell-2 psr(3/19/21) to msft delivery)',
#   'delay in colo-4- cell-3 mer delivery (duration = colo-4 cell-3 psr(3/26/21) to msft delivery)',
#   'delay in colo-1- cell-4 mer delivery (duration = colo1 cell-4 psr(11/30/20) to msft delivery)',
#   'delay in colo-2- cell-4 mer delivery (duration = colo 2- cell-4 psr(1/5/21) to msft delivery)',
#   'delay in colo-3 cell-4 mer delivery (duration = colo-3 cell-4 psr(2/19/21) to msft delivery)',
#   'delay in colo-4- cell-4 mer delivery (duration = colo-4 cell-4 psr(4/2/21) to msft delivery)',
#   'wire mesh procurement delay',
#   'delay in upm delivery (duration = colo2 cell-1 11/25 to msft delivery)',
#   'delay in upm delivery (duration = colo2 cell-2 11/25 to msft delivery)',
#   'delay in upm delivery (duration = colo2 cell-3 11/25 to msft delivery)',
#   'delay in upm delivery (duration = colo2 cell-4 11/25 to msft delivery)',
#   'delay in upm delivery (duration = colo3 cell-1 psr 11/23 to msft delivery)',
#   'delay in upm delivery (duration = colo3 cell-2 11/23 to msft delivery)',
#   'delay in upm delivery (duration = colo3 cell-3 11/23 to msft delivery)',
#   'delay in upm delivery (duration = colo3 cell-4 11/23 to msft delivery)',
#   'delay in upm delivery (duration = colo4 cell-1 12/7 to msft delivery)',
#   'delay in upm delivery (duration = colo4 cell-2 12/7 to msft delivery)',
#   'delay in upm delivery (duration = colo4 cell-3 12/18 to msft delivery)',
#   'delay in upm delivery (duration = colo4 cell-4 12/18 to msft delivery)',
#   'delay in ums delivery (duration =  (9/19) to msft delivery)',
#   'delay in colo-2 cell-1 generator (duration= colo-2 cell-1 psr(10/12/20) to msft delivery)',
#   'delay in colo-2 cell-2 generator (duration= colo-2 cell-2 psr(11/6/20) to msft delivery)',
#   'delay in colo-2 cell-4 generator (duration= colo-2 cell-4 psr(11/21/20) to msft delivery)',
#   'delay in colo-2 cell-3 generator (duration= colo-2 cell-3 psr(10/22/20) to msft delivery)',
#   'delay in colo-3 cell-1 generator (duration= colo-3 cell-1 psr(10/12/20) to msft delivery)',
#   'delay in colo-3 cell-2 generator (duration= colo-3 cell-2 psr(11/6/20) to msft delivery)',
#   'delay in colo-3 cell-4 generator (duration= colo-3 cell-4 psr(11/21/20) to msft delivery)',
#   'delay in colo-3 cell-3 generator (duration= colo-3 cell-3 psr(10/22/20) to msft delivery)',
#   'delay in colo-4 cell-1 generator (duration= colo-4 cell-1 psr(10/12/20) to msft delivery)',
#   'delay in colo-4 cell-2 generator (duration= colo-4 cell-2 psr(11/6/20) to msft delivery)',
#   'delay in colo-4 cell-4 generator (duration= colo-4 cell-4 psr(11/21/20) to msft delivery)',
#   'delay in colo-4 cell-3 generator (duration= colo-4 cell-3 psr(10/22/20) to msft delivery)',
#   'delay in colo-1 cell-1 generator (duration= colo-1 cell-1 psr(9/15/20) to msft delivery)',
#   'delay in colo-1 cell-2 generator (duration= colo-1 cell-2 psr(9/15/20) to msft delivery)',
#   'delay in colo-1 cell-4 generator (duration= colo-1 cell-4 psr(9/29/20) to msft delivery)',
#   'delay in colo-1 cell-3 generator (duration= colo-1 cell-3 psr(9/29/20) to msft delivery)',
#   '6.1-92 colo-1 sf/ rf startup delay (vendor schedule availability)',
#   '6.1-93 colo-1 hvac minisplits startup delay (vendor schedule availability)',
#   "6.1-95 colo-1 ats's l3 startup delay (vendor schedule availability)",
#   '6.1-96 colo-1 pdu - epms l3 startup delay (vendor schedule availability)',
#   'colo-3 delay in se uploading qc checkilst'],
#  'site': ['delay#15 wa state l&i mer onsite inspection delay due to covid-19',
#   'delay#34 site stand-down (diversity training)',
#   'telecom-communications site loop/ductbank',
#   'site water / fire loop',
#   'site storm',
#   'site sanitary',
#   'landscape and site specialties',
#   'site lighting',
#   'mobilize on site',
#   'site temp power procurement & infrastructure',
#   'off-site bim modeling & coordination',
#   'site work complete',
#   'site- neher mcgrath study drb#1 jaz to ums/urs & upm to ums',
#   'remaining site sanitary',
#   'site shut down - 9/9/2020',
#   'site shut down - 9/10/2020',
#   'site shut down - 9/11/2020',
#   'site shut down - 9/12/2020',
#   'site shut down - 9/14/2020',
#   'site shut down - 9/15/2020',
#   'site shut down - 9/16/2020',
#   'colo-1 cell-1 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-1 cell-3 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-1 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-1 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-1 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-3 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-1 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-3 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-4 cell-1 wa state l&i onsite checkup & approval to connect to mer',
#   'colo-4 cell-3 wa state l&i onsite checkup & approval to connect to mer',
#   'colo-4 cell-2 wa state l&i onsite checkup & approval to connect to mer',
#   'colo-4 cell-4 wa state l&i onsite checkup & approval to connect to mer',
#   '6.1.46- site upm inspections'],
#  'general': [],
#  'admin/colo1': ['mdc1 admin/colo1 - lv3 cx complete (co-66: 20-aug-21)',
#   'mdc1 admin/colo1 - fitout summary'],
#  'fitout': ['colo 2 fitout',
#   'colo 3 fitout',
#   'colo 4 fitout',
#   'mdc1 admin/colo1 - fitout summary',
#   'mdc1 colo2 - fitout summary',
#   'mdc1 colo3 - fitout summary',
#   'mdc1 colo4 - fitout summary'],
#  'commissioning': ['security commissioning (level2 with corp net after ist)',
#   'security commissioning (level2 with corp net after ist)',
#   'security commissioning (level2 with corp net after ist)',
#   'security commissioning (level2 with corp net after ist)',
#   'security commissioning (level3 dcps)',
#   'security commissioning (level3 dcps)',
#   'security commissioning (level3 dcps)',
#   'security commissioning (level3 dcps)'],
#  'colo-2': ['colo-2 cx',
#   'colo-2 cell-1',
#   'colo-2 cell-3',
#   'colo-2 cell-2',
#   'colo-2 cell-4',
#   'colo-2 adp01 & adp02 equipment shift',
#   'level 3 cx- colo-2',
#   'pad ready for mer colo-2 cell-1',
#   'pad ready for mer colo-2 cell-3',
#   'pad ready for mer colo-2 cell-2',
#   'pad ready for mer colo-2 cell-4',
#   'duct bank- colo-2 upm to north valut',
#   'vault- set 2nd vault along ums duct run near colo-2',
#   'duct bank colo-2 upm to vault',
#   'pull cross overs- colo-2 cell-3 to cell-4',
#   'pul upm to upm colo-2- cell-1 to cell-3',
#   'pull upm to upm colo-2 cell 2- cell - 4',
#   'pull- urs to colo-2',
#   'ahu - roj colo-2 cell- 1',
#   'msft delivery -ahu - roj colo-2 cell- 3',
#   'ahu - roj colo-2 cell- 2',
#   'ahu - roj colo-2 cell- 4',
#   'msft delivery -ahu - roj colo-2 cell- 1',
#   'ahu - roj colo-2 cell- 3',
#   'msft delivery -ahu - roj colo-2 cell- 2',
#   'msft delivery -ahu - roj colo-2 cell- 4',
#   'pdu roj colo-2 cell-1',
#   'msft delivery -pdu roj colo-2 cell-1',
#   'pdu roj colo-2 cell-3',
#   'msft delivery -pdu roj colo-2 cell-3',
#   'pdu roj colo-2 cell-2',
#   'msft delivery -pdu roj colo-2 cell-2',
#   'pdu roj colo-2 cell-4',
#   'msft delivery -pdu roj colo-2 cell-4',
#   'punch list colo-2',
#   'construction server- colo-2',
#   'msft delivery - colo-2,3,4 gen submittal approval',
#   'set- colo-2 ums',
#   'pad- colo-2 ums',
#   'duct bank - ums02 to upm colo-2 cell-1',
#   'pull- ums02- upm colo-2 cell-1',
#   'ums - roj colo-2',
#   'delay in colo-2- cell-1 mer delivery (duration = colo1 cell-1 psr(12/15/20) to msft delivery)',
#   'delay in colo-2- cell-2 mer delivery (duration = colo 2 cell-2 psr(12/22/20) to msft delivery)',
#   'delay in colo-2- cell-3 mer delivery (duration = colo 2- cell-3 psr(12/28/20) to msft delivery)',
#   'delay in colo-2- cell-4 mer delivery (duration = colo 2- cell-4 psr(1/5/21) to msft delivery)',
#   'delay in colo-2 cell-1 generator (duration= colo-2 cell-1 psr(10/12/20) to msft delivery)',
#   'delay in colo-2 cell-2 generator (duration= colo-2 cell-2 psr(11/6/20) to msft delivery)',
#   'delay in colo-2 cell-4 generator (duration= colo-2 cell-4 psr(11/21/20) to msft delivery)',
#   'delay in colo-2 cell-3 generator (duration= colo-2 cell-3 psr(10/22/20) to msft delivery)',
#   'colo-2 cell-1 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-3 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   "yellow tagging for colo-2 upm's",
#   'upm yellow tagging -colo-2 cell-1',
#   'upm yellow tagging -colo-2 cell-3',
#   'upm yellow tagging - colo-2 cell-2',
#   'upm yellow tagging -colo-2 cell-4',
#   'colo-2 cell-2 awaiting se revised tool ""come along"" for mer lift & set',
#   'colo-2 cell-1 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-3 awaiting se revised tool ""come along"" for mer lift & set',
#   '6.1.37- 6.2.01- ground fault setting on colo-2 gen mcb01',
#   'colo-2 cell-1 remove/ replace busway & hangers',
#   'colo-2 cell-2 remove/ replace busway & hangers',
#   'colo-2 cell-1 rearrange roxtec blocks per coordination layout',
#   'colo-2 cell-1 interior mer conduit installation building side',
#   'colo-2 cell3 rearrange roxtec blocks per coordination layout',
#   'colo-2 cell3 interior mer conduit installation building side',
#   'colo-2 cell2 rearrange roxtec blocks per coordination layout (delete)',
#   'colo-2 cell2 interior mer conduit installation building (delete)',
#   'colo-2 cell-4 rearrange roxtec blocks per coordination layout',
#   'colo-2 cell-1 mer flex conduit fixes',
#   'colo-2 cell-3 mer flex conduit fixes',
#   'colo-2 cell-2 mer flex conduit fixes',
#   'colo-2 cell-4 mer flex conduit fixes',
#   'colo-2 cell-3 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-4 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-1 se install ups batteries in cabinet',
#   'colo-2 cell-4 se install ups batteries in cabinet',
#   'colo-2 cell-3 se install ups batteries in cabinet',
#   'colo-2 cell-2 se install ups batteries in cabinet',
#   'neta test validation inpections- veca-eps-rts colo-2 cell-1',
#   'neta test validation inpections- veca-eps-rts colo-2 cell-3',
#   'neta test validation inpections- veca-eps-rts colo-2 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-2 cell-4',
#   'colo-2 cell-1 install missing raceway & bussing within generator',
#   'colo-2 cell-1 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-2 cell-3 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-2 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-2 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-2 cell-2 install missing raceway & bussing within generator',
#   'colo-2 cell-3 install missing raceway & bussing within generator',
#   'colo-2 cell-4 install missing raceway & bussing within generator',
#   'nopc-18 remove colo-2 cell-1 transformer',
#   'nopc-18 remove colo-2 cell-2 transformer',
#   'nopc-18 remove colo-2 cell-3 transformer',
#   'nopc-18 remove colo-2 cell-4 transformer',
#   '6.1.55-colo-2 - fc factoy re-wire (rfi-502)',
#   '6.1.01.1 mer 10a hrg retrofit colo-2 cell-1',
#   '6.1.01.4 mer 10a hrg retrofit colo-2 cell-4',
#   '6.1.01.3 mer 10a hrg retrofit colo-2 cell-3',
#   '6.1.01.2 mer 10a hrg retrofit colo-2 cell-2',
#   'nopc-18 reinstall colo-2 cell-1 transformer',
#   'nopc-18 reinstall colo-2 cell-2 transformer',
#   'nopc-18 reinstall colo-2 cell-3 transformer',
#   'nopc-18 reinstall colo-2 cell-4 transformer',
#   'colo-2 cell-1 mer-ups battery disconnect modifications rework',
#   'colo-2 cell-2 mer-ups battery disconnect modifications rework',
#   'colo-2 cell-3 mer-ups battery disconnect modifications rework',
#   'colo-2 cell-4 mer-ups battery disconnect modifications rework',
#   '6.2-08 colo-2 cell- 1,2 mer equipment phenolic labelling',
#   '6.2-08 colo-2 cell- 3,4 mer equipment phenolic labelling',
#   '6.2-12 colo-2 all cells- factory connection torque verification',
#   'csa punchlist - colo-2',
#   'mep punchlist - colo-2',
#   'ae/owner punchlist - colo-2',
#   'colo-2 cell-1 ups pnl01 compass issues preventing cyt',
#   'colo-2 cell-2 ups pnl01 compass issues preventing cyt',
#   'colo-2 cell-3 ups pnl01 compass issues preventing cyt',
#   'colo-2 cell-4 ups pnl01 compass issues preventing cyt',
#   'colo-2 cell-1 open issues preventing yellow tags mer equipment',
#   'colo-2 cell-2 open issues preventing yellow tags mer equipment',
#   'colo-2 cell-3 open issues preventing yellow tags mer equipment',
#   'colo-2 cell-4 open issues preventing yellow tags mer equipment'],
#  'colo-3': ['colo-3 cx',
#   'delay#36- nopc-21 colo-3 & 4 mer cable bus access space constraint',
#   'delay#37- nopc-24 colo-3 mer raceway constraints',
#   'colo-3 cell-1',
#   'colo-3 cell-3',
#   'colo-3 cell-2',
#   'colo-3 cell-4',
#   'colo-3 adp01 & adp02 equipment shift',
#   'level 3 cx- colo-3',
#   'pad ready for mer colo-3 cell-1',
#   'pad ready for mer colo-3 cell-3',
#   'pad ready for mer colo-3 cell-2',
#   'pad ready for mer colo-3 cell-4',
#   'duct bank - colo-3 upm to vault ums run',
#   'duct bank - vault to colo-3 upm',
#   'duct bank - colo-3 upm to upm',
#   'pull cross overs- colo-3 cell-3 to cell-4',
#   'pull upm to upm colo-3 - cell-1 to cell-3',
#   'pull upm to upm colo-3 cell 2- cell - 4',
#   'pull- urs to colo-3',
#   'ahu - roj colo-3 cell- 1',
#   'ahu - roj colo-3 cell- 3',
#   'ahu - roj colo-3 cell- 2',
#   'ahu - roj colo-3 cell- 4',
#   'msft delivery -ahu - roj colo-3 cell- 1',
#   'msft delivery -ahu - roj colo-3 cell- 3',
#   'msft delivery -ahu - roj colo-3 cell- 2',
#   'msft delivery -ahu - roj colo-3 cell- 4',
#   'pdu roj colo-3 cell-1',
#   'msft delivery -pdu roj colo-3 cell-1',
#   'pdu roj colo-3 cell-3',
#   'msft delivery -pdu roj colo-3 cell-3',
#   'pdu roj colo-3 cell-2',
#   'msft delivery -pdu roj colo-3 cell-2',
#   'pdu roj colo-3 cell-4',
#   'msft delivery -pdu roj colo-3 cell-4',
#   'punch list colo-3',
#   'construction server- colo-3',
#   'set- colo-3 ums',
#   'pad- colo-3 ums',
#   'duct bank - ums03 to upm colo-3 cell-1',
#   'pull- ums03- upm colo-3 cell-1',
#   'ums - roj colo-3',
#   'delay in colo-3- cell-1 mer delivery (duration = colo-3 cell-1 psr(1/29/21) to msft delivery)',
#   'delay in colo-3- cell-2 mer delivery (duration = colo-3 cell-2 psr(2/5/21) to msft delivery)',
#   'delay in colo-3 cell-3 mer delivery (duration = colo-3 cell-3 psr(2/12/21) to msft delivery)',
#   'delay in colo-3 cell-4 mer delivery (duration = colo-3 cell-4 psr(2/19/21) to msft delivery)',
#   'colo-3 cell-1 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-3 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   'delay in colo-3 cell-1 generator (duration= colo-3 cell-1 psr(10/12/20) to msft delivery)',
#   'delay in colo-3 cell-2 generator (duration= colo-3 cell-2 psr(11/6/20) to msft delivery)',
#   'delay in colo-3 cell-4 generator (duration= colo-3 cell-4 psr(11/21/20) to msft delivery)',
#   'delay in colo-3 cell-3 generator (duration= colo-3 cell-3 psr(10/22/20) to msft delivery)',
#   "yellow tagging for colo-3 upm's",
#   'upm yellow tagging -colo-3 cell-1',
#   'upm yellow tagging -colo-3 cell-3',
#   'upm yellow tagging -colo-3 cell-2',
#   'upm yellow tagging colo-3 cell-4',
#   'colo-3 cell-1 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-3 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-4 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-1 se install ups batteries in cabinet',
#   'colo-3 cell-4 se install ups batteries in cabinet',
#   'colo-3 cell-3 se install ups batteries in cabinet',
#   'colo-3 cell-2 se install ups batteries in cabinet',
#   'neta test validation inpections- veca-eps-rts colo-3 cell-1',
#   'neta test validation inpections- veca-eps-rts colo-3 cell-3',
#   'neta test validation inpections- veca-eps-rts colo-3 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-3 cell-4',
#   '6.1.39.1- colo-3 cell-1  gen belly tank failed pressure test',
#   '6.1.39.2- colo-3 cell-1 replace belly tank and set gen',
#   'colo-3 cell-1 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-3  cell-3 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-3 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-3 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-3 cell-1 install missing raceway & bussing within generator',
#   'colo-3 cell-2 install missing raceway & bussing within generator',
#   'colo-3 cell-3 install missing raceway & bussing within generator',
#   'colo-3 cell-4 install missing raceway & bussing within generator',
#   'nopc-18 remove colo-3 cell-1 transformer',
#   'nopc-18 remove colo-3 cell-2 transformer',
#   'nopc-18 remove colo-3 cell-3 transformer',
#   'nopc-18 remove colo-3 cell-4 transformer',
#   '6.1.55-colo-3 - fc factoy re-wire (rfi-502)',
#   '6.1.01.1 mer 10a hrg retrofit colo-3 cell-1',
#   '6.1.01.4 mer 10a hrg retrofit colo-3 cell-4',
#   '6.1.01.3 mer 10a hrg retrofit colo-3 cell-3',
#   '6.1.01.2 mer 10a hrg retrofit colo-3 cell-2',
#   'nopc-18 reinstall colo-3 cell-1 transformer',
#   'nopc-18 reinstall colo-3 cell-2 transformer',
#   'nopc-18 reinstall colo-3 cell-3 transformer',
#   'nopc-18 reinstall colo-3 cell-4 transformer',
#   'colo-3 cell-3 remove inaccessible tray in mer',
#   'colo-3 cell-3 reinstall tray in mer',
#   'colo-3 cell-1 mer-ups battery disconnect modifications rework',
#   'colo-3 cell-2 mer-ups battery disconnect modifications rework',
#   'colo-3 cell-3 mer-ups battery disconnect modifications rework',
#   'colo-3 cell-4 mer-ups battery disconnect modifications rework',
#   'colo-3 cell-4 remove inaccessible tray in mer',
#   'colo-3 cell-4 reinstall tray in mer',
#   'colo-3 cell-1 remove inaccessible tray in mer',
#   'colo-3 cell-1 reinstall tray in mer',
#   'colo-3 cell-2 remove inaccessible tray in mer',
#   'colo-3 cell-2 reinstall tray in mer',
#   'colo-3 cell-3 conduit rework',
#   'csa punchlist - colo-3',
#   'mep punchlist - colo-3',
#   'ae/owner punchlist - colo-3',
#   'colo-3 delay in se uploading qc checkilst'],
#  'colo-4': ['colo-4 cx',
#   'delay#38 nopc-25 colo-4 mer raceway constraints',
#   'colo-4 cell-1',
#   'colo-4 cell-3',
#   'colo-4 cell-2',
#   'colo-4 cell-4',
#   'colo-4 adp01 & adp02 equipment shift',
#   'level 3 cx - colo-4',
#   'pad ready for mer colo-4 cell-1',
#   'pad ready for mer colo-4 cell-3',
#   'pad ready for mer colo-4 cell-2',
#   'pad ready for mer colo-4 cell-4',
#   'duct bank - colo-4 upm to ums',
#   'duct bank - vault to colo-4 upm',
#   'duct bank - colo-4 upm to upm',
#   'pull cross overs- colo-4 cell-3 to cell-4',
#   'pull upm to upm colo-4 - cell-1 to cell-3',
#   'pull upm to upm colo-4 cell 2- cell - 4',
#   'pull- urs to colo-4',
#   'pull- ums to colo-4',
#   'msft delivery -ahu - roj colo-4 cell- 1',
#   'ahu - roj colo-4 cell- 3',
#   'ahu - roj colo-4 cell- 2',
#   'ahu - roj colo-4 cell- 4',
#   'ahu - roj colo-4 cell- 1',
#   'msft delivery -ahu - roj colo-4 cell- 3',
#   'msft delivery -ahu - roj colo-4 cell- 2',
#   'msft delivery -ahu - roj colo-4 cell- 4',
#   'upm - roj - colo-4 cell- 1',
#   'msft delivery -upm - roj - colo-4 cell- 1 (12/7/2020)',
#   'upm - roj - colo-4 cell- 3',
#   'msft delivery -upm - roj - colo-4 cell- 3 (12/18/2020)',
#   'msft delivery -upm - roj - colo-4 cell- 2 (12/7/2020)',
#   'upm - roj - colo-4 cell- 2',
#   'upm - roj - colo-4 cell- 4',
#   'msft delivery -upm - roj - colo-4 cell- 4 (12/18/2020)',
#   'pdu roj colo-4 cell-1',
#   'msft delivery -pdu roj colo-4 cell-1',
#   'pdu roj colo-4 cell-3',
#   'msft delivery -pdu roj colo-4 cell-3',
#   'pdu roj colo-4 cell-2',
#   'msft delivery -pdu roj colo-4 cell-2',
#   'pdu roj colo-4 cell-4',
#   'msft delivery -pdu roj colo-4 cell-4',
#   'punch list colo-4',
#   'construction server- colo-4',
#   'set- colo-4 ums',
#   'pad- colo-4 ums',
#   'duct bank - ums04 to upm colo-4 cell-1',
#   'pull- ums04- upm colo-4 cell-1',
#   'ums - roj colo-4',
#   'delay in colo-4- cell-1 mer delivery (duration= colo-4 cell-1 psr(3/12/21) to msft delivery)',
#   'delay in colo-4- cell-2 mer delivery (duration = colo-4 cell-2 psr(3/19/21) to msft delivery)',
#   'delay in colo-4- cell-3 mer delivery (duration = colo-4 cell-3 psr(3/26/21) to msft delivery)',
#   'delay in colo-4- cell-4 mer delivery (duration = colo-4 cell-4 psr(4/2/21) to msft delivery)',
#   'colo-4 cell-1 wa state l&i onsite checkup & approval to connect to mer',
#   'colo-4 cell-3 wa state l&i onsite checkup & approval to connect to mer',
#   'colo-4 cell-2 wa state l&i onsite checkup & approval to connect to mer',
#   'colo-4 cell-4 wa state l&i onsite checkup & approval to connect to mer',
#   'delay in colo-4 cell-1 generator (duration= colo-4 cell-1 psr(10/12/20) to msft delivery)',
#   'delay in colo-4 cell-2 generator (duration= colo-4 cell-2 psr(11/6/20) to msft delivery)',
#   'delay in colo-4 cell-4 generator (duration= colo-4 cell-4 psr(11/21/20) to msft delivery)',
#   'delay in colo-4 cell-3 generator (duration= colo-4 cell-3 psr(10/22/20) to msft delivery)',
#   "yellow tagging for colo-4 upm's",
#   'upm yellow tagging -colo-4 cell-1',
#   'upm yellow tagging -colo-4 cell-3',
#   'upm yellow tagging -colo-4 cell-2',
#   'upm yellow tagging -colo-4 cell-4',
#   'colo-4 cell-1 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-3 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-4 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-1 se install ups batteries in cabinet',
#   'colo-4 cell-4 se install ups batteries in cabinet',
#   'colo-4 cell-3 se install ups batteries in cabinet',
#   'colo-4 cell-2 se install ups batteries in cabinet',
#   'neta test validation inpections- veca-eps-rts colo-4 cell-1',
#   'neta test validation inpections- veca-eps-rts colo-4 cell-3',
#   'neta test validation inpections- veca-eps-rts colo-4 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-4 cell-4',
#   'colo-4 cell-1 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-4 cell-3 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-4 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-4 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-4 cell-1 install missing raceway & bussing within generator',
#   'colo-4 cell-2 install missing raceway & bussing within generator',
#   'colo-4 cell-3 install missing raceway & bussing within generator',
#   'colo-4 cell-4 install missing raceway & bussing within generator',
#   '6.2.03- replace damaged upm in colo-4 cell-4',
#   'nopc-18 remove colo-4 cell-1 transformer',
#   'nopc-18 remove colo-4 cell-2 transformer',
#   'nopc-18 remove colo-4 cell-3 transformer',
#   'nopc-18 remove colo-4 cell-4 transformer',
#   '6.1.55-colo-4 - fc factoy re-wire (rfi-502)',
#   '6.1.01.1 mer 10a hrg retrofit colo-4 cell-1',
#   '6.1.01.4 mer 10a hrg retrofit colo-4 cell-4',
#   '6.1.01.3 mer 10a hrg retrofit colo-4 cell-3',
#   '6.1.01.2 mer 10a hrg retrofit colo-4 cell-2',
#   'nopc-18 reinstall colo-4 cell-1 transformer',
#   'nopc-18 reinstall colo-4 cell-2 transformer',
#   'nopc-18 reinstall colo-4 cell-3 transformer',
#   'nopc-18 reinstall colo-4 cell-4 transformer',
#   'colo-4 cell-1 mer-ups battery disconnect modifications rework',
#   'colo-4 cell-2 mer-ups battery disconnect modifications rework',
#   'colo-4 cell-3 mer-ups battery disconnect modifications rework',
#   'colo-4 cell-4 mer-ups battery disconnect modifications rework',
#   'colo-4 cell-1 remove inaccessible tray in mer',
#   'colo-4 cell-1 reinstall tray in mer',
#   'colo-4 cell-2 remove inaccessible tray in mer',
#   'colo-4 cell-2 reinstall tray in mer',
#   'colo-4 cell-3 remove inaccessible tray in mer',
#   'colo-4 cell-3 reinstall tray in mer',
#   'colo-4 cell-4 remove inaccessible tray in mer4',
#   'colo-4 cell-4 reinstall tray in mer',
#   '#4. extreme heat - 6/28/21- 7/2/21(effecting colo-4 yard work)',
#   'colo-4 cell-1 conduit rework',
#   'colo-4 cell-2 conduit rework',
#   'colo-4 cell-3 conduit rework',
#   'colo-4 cell-4 conduit rework',
#   'csa punchlist - colo-4',
#   'mep punchlist - colo-4',
#   'ae/owner punchlist - colo-4'],
#  'update#4': [],
#  'punchlist': ['a/e & owner-rep punchlist walk',
#   'complete a/e punchlist',
#   'a/e & owner-rep punchlist walk',
#   'complete a/e punchlist',
#   'a/e & owner-rep punchlist walk',
#   'complete a/e punchlist',
#   'a/e & owner-rep punchlist walk',
#   'complete a/e punchlist',
#   'csa punchlist - colo-1',
#   'csa punchlist - colo-2',
#   'csa punchlist - colo-3',
#   'csa punchlist - colo-4',
#   'mep punchlist - colo-1',
#   'mep punchlist - colo-2',
#   'mep punchlist - colo-3',
#   'mep punchlist - colo-4',
#   'ae/owner punchlist - colo-1',
#   'ae/owner punchlist - colo-2',
#   'ae/owner punchlist - colo-3',
#   'ae/owner punchlist - colo-4'],
#  'update#6': [],
#  'update#7': [],
#  'update#8': [],
#  'update#10': [],
#  'update#12': [],
#  'admin': ['admin/ colo-1',
#   'admin/ colo 1',
#   'admin/colo 1',
#   'delay#20 admin gen missing bussing',
#   'delay#25 veca safety standown due to admin gen unplanned enegization',
#   'delay#32 missing admin arc flash labels (rfi-520)',
#   'admin/ colo-1',
#   'exterior equipment admin',
#   'mdc1 admin/colo1 - lv3 cx complete (co-66: 20-aug-21)',
#   'admin/colo-1 network startup',
#   'level 3 cx - admin and colo1',
#   'mdc1 admin/colo1 - fitout summary',
#   'admin -electrical underground rough-in',
#   'foundation start - admin/colo 1',
#   'steel erection - admin/colo 1',
#   'fit out start - admin/colo 1',
#   'sog- admin/ colo1 start',
#   'insulated metal panel start- admin/colo 1',
#   'roof panel start -admin/colo 1',
#   'lead time for admin/colo 1 yard steel',
#   'admin / colo 1 csa complete',
#   'punch list - admin/colo 1',
#   'admin/colo-1 bim signoff',
#   'duct back- admin upm to vault',
#   'duct bank admin upm to colo-1 upm',
#   'pull upm to upm admin to colo-1 cell -2',
#   'pull- urs to admin',
#   'ist admin/colo 1',
#   'msft delivery - admin gen submittal release',
#   'msft delivery -admin- gen- roj',
#   'msft delivery - admin - upm - roj',
#   'admin gen- roj',
#   'admin overhead rough-in (drb#2)',
#   'admin electrical room build out (drb#2)',
#   'admin lighting installation (drb#2)',
#   'term admin - upm',
#   'tco admin/colo 1',
#   'substantial completion admin/colo 1',
#   'lock down admin/colo 1',
#   'term admin - upm',
#   'linx mobilization to admin/colo-1',
#   'admin gen scr testing and burnins',
#   'upm yellow tagging - admin & colo-1 cell-1',
#   'lead time for missing admin gen bussing',
#   'admin gen bussing install',
#   'all construction activities -safety standown due to admin gen unplanned energization',
#   'admin - neta test validation inpections- veca-eps-rts admin',
#   '6.1.41 - incorrect lugs for admin gen main bussing',
#   '6.1.54- tcm awaiting admin siemens break tank parts',
#   'print new dc arc flash labels for admin elp',
#   'admin-ups battery disconnect modifications rework',
#   'rfi-552 admin msb to ups battery disconnect solution approval',
#   '6.1-98 admin/colo-1 asco epms connectivity issues',
#   "6.1-88  admin/ colo-1 mer/admin ups l3 testing (includes shutdown to move pqm's & pqm data post proccessing)"],
#  'colo-1': ['admin/ colo-1',
#   'colo-1 cx',
#   'colo-1 fit out',
#   'admin/ colo-1',
#   'colo-1 cell-1',
#   'colo-1 cell-2',
#   'colo-1 cell-3',
#   'colo-1 cell-4',
#   'colo-1 adp01 & adp02 equipment shift',
#   'admin/colo-1 network startup',
#   'admin/colo-1 bim signoff',
#   'pad ready for mer colo-1 cell-1',
#   'pad ready for mer colo-1 cell-3',
#   'pad ready for mer colo-1 cell-2',
#   'pad ready for mer colo-1 cell-4',
#   'duct bank- colo-1 upm to north vault',
#   'duct bank admin upm to colo-1 upm',
#   'pull cross overs- colo-1 cell-3 to cell-4',
#   'pull upm to upm colo-1 - cell-1 to cell-3',
#   'pull upm to upm admin to colo-1 cell -2',
#   'pull upm to upm colo-1 cell 2- cell - 4',
#   'pull- ums to colo-1,2,3',
#   'ahu - roj colo-1 cell- 1',
#   'ahu - roj colo-1 cell- 3',
#   'ahu - roj colo-1 cell- 2',
#   'ahu - roj colo-1 cell- 4',
#   'msft delivery -ahu - roj colo-1 cell- 1(11/2/20)',
#   'msft delivery -ahu - roj colo-1 cell- 3',
#   'msft delivery -ahu - roj colo-1 cell- 2 (11/2/20)',
#   'msft delivery -ahu - roj colo-1 cell- 4',
#   'upm roj colo-1 cell-1',
#   'msft delivery -upm roj colo-1 cell-1 (psr roj -9/19/2020)',
#   'upm roj colo-1 cell-3',
#   'msft delivery -upm roj colo-1 cell-3 (psr roj -9/28/2020)',
#   'msft delivery -upm roj colo-1 cell-2 (psr roj -10/13/2020)',
#   'upm roj colo-1 cell-2',
#   'upm roj colo-1 cell-4',
#   'msft delivery -upm roj colo-1 cell-4 (psr roj -10/28/2020)',
#   'pdu roj colo-1 cell-1',
#   'msft delivery -pdu roj colo-1 cell-1',
#   'pdu roj colo-1 cell-3',
#   'msft delivery -pdu roj colo-1 cell-3',
#   'pdu roj colo-1 cell-2',
#   'msft delivery -pdu roj colo-1 cell-2',
#   'pdu roj colo-1 cell-4',
#   'msft delivery -pdu roj colo-1 cell-4',
#   'construction server- colo-1',
#   'msft delivery - colo-1 gen submittal release',
#   'msft delivery - mer submittal colo-1',
#   'water treatment delivery colo-1',
#   'set- colo-1 ums',
#   'pad- colo-1 ums',
#   'duct bank - ums01 to upm colo-1 cell-1',
#   'pull- ums01- upm colo-1 cell-1',
#   'delay in colo-1- cell-1 mer delivery (duration = colo1 cell-1 psr(11/6/20) to msft delivery)',
#   'delay in colo-1- cell-2 mer delivery (duration = colo1 cell-2 psr(11/13/20) to msft delivery)',
#   'delay in colo-1- cell-3 mer delivery (duration = colo1 cell-3 psr(11/20/20) to msft delivery)',
#   'delay in colo-1- cell-4 mer delivery (duration = colo1 cell-4 psr(11/30/20) to msft delivery)',
#   'linx mobilization to admin/colo-1',
#   'colo-1 cell-1 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-1 cell-3 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-1 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-1 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   'delay in colo-1 cell-1 generator (duration= colo-1 cell-1 psr(9/15/20) to msft delivery)',
#   'delay in colo-1 cell-2 generator (duration= colo-1 cell-2 psr(9/15/20) to msft delivery)',
#   'delay in colo-1 cell-4 generator (duration= colo-1 cell-4 psr(9/29/20) to msft delivery)',
#   'delay in colo-1 cell-3 generator (duration= colo-1 cell-3 psr(9/29/20) to msft delivery)',
#   'upm yellow tagging - admin & colo-1 cell-1',
#   'colo-1 cell-1 rearrange roxtec blocks per coordination layout',
#   'colo-1 cell-1 interior mer conduit installation building side complete march1st (mer discovery corrections & signoff)',
#   'colo-1 cell-1 mer flex conduit fixes',
#   'colo-1 cell-1 remove/ replace busway & hangers',
#   'colo-1 cell-3 remove/ replace busway & hangers',
#   'colo-1 cell-2 remove/ replace busway & hangers',
#   'colo-1 cell-4 remove/ replace busway & hangers',
#   'colo-1 cell-3 mer flex conduit fixes',
#   'colo-1 cell-2 mer flex conduit fixes',
#   'colo-1 cell-4 mer flex conduit fixes',
#   'colo-1 cell3 rearrange roxtec blocks per coordination layout',
#   'colo-1 cell3 interior mer conduit installation building side',
#   'colo-1 cell2 rearrange roxtec blocks per coordination layout',
#   'colo-1 cell2 interior mer conduit installation building side',
#   'colo-1 cell4 rearrange roxtec blocks per coordination layout',
#   'colo-1 cell4 interior mer conduit installation building side',
#   'upm yellow tagging - colo-1 cell-3',
#   'upm yellow tagging - colo-1 cell-2',
#   'upm yellow tagging - colo-1 cell-4',
#   'colo-1 cell-1 se install ups batteries in cabinet',
#   'colo-1 cell-4 se install ups batteries in cabinet',
#   'colo-1 cell-3 se install ups batteries in cabinet',
#   'colo-1 cell-2 se install ups batteries in cabinet',
#   '6.1.34.1 colo-1 cell-1 rework on ats input conductors',
#   'neta test validation inpections- veca-eps-rts colo-1 cell-1',
#   '6.1.34.2 colo-1 cell-2 rework on ats input conductors',
#   '6.1.34.3 colo-1 cell-3 rework on ats input conductors',
#   '6.1.34.4 colo-1 cell-4 rework on ats input conductors',
#   'colo-1 cell-1 field modification of tray',
#   'colo-1 cell-2 field modification of tray',
#   '6.1.01.1 mer 10a hrg retrofit colo-1 cell-1',
#   '6.1.01.4 mer 10a hrg retrofit colo-1 cell-4',
#   '6.1.01.3 mer 10a hrg retrofit colo-1 cell-3',
#   '6.1.01.2 mer 10a hrg retrofit colo-1 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-1 cell-3',
#   'neta test validation inpections- veca-eps-rts colo-1 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-1 cell-4',
#   '6.1.47- colo-1 cell-2 ups01- factory test thermal event',
#   'colo-1 cell-1 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-1 cell-3 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-1 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-1 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'nopc-18 remove colo-1 cell-1 transformer',
#   'nopc-18 remove colo-1 cell-2 transformer',
#   'nopc-18 remove colo-1 cell-3 transformer',
#   'nopc-18 remove colo-1 cell-4 transformer',
#   '6.1.51-colo-1 cell-1,2 factory conductors not terminated per drawings',
#   '6.1.55-colo-1 - fc factoy re-wire (rfi-502)',
#   '6.1.49 - colo-1 cell-1 awaiting ground lug solution, procurement, installation of labelling ats 01-06',
#   '6.1.53-colo-1 cell-1,2 ups01, pnl01 awaiting missing breakers',
#   '6.1.53-colo-1 cell-1,2,3,4 ups01, pnl01 install/ term missing breakers',
#   '6.1.59 (6.1.51 carryover) -colo-1 cell-1,2 factory conductors exertherm corrections',
#   'nopc-18 reinstall colo-1 cell-1 transformer',
#   'nopc-18 reinstall colo-1 cell-2 transformer',
#   'nopc-18 reinstall colo-1 cell-3 transformer',
#   'nopc-18 reinstall colo-1 cell-4 transformer',
#   '6.1.58-rfi-528- colo-1 - sf/rf circuitry & terminal block rework',
#   '6.1.56 - colo-1 awaiting msb/adp ground lug replacements, installation of labelling',
#   'colo-1 cell-1 mer-ups battery disconnect modifications rework',
#   'colo-1 cell-2 mer-ups battery disconnect modifications rework',
#   'colo-1 cell-3 mer-ups battery disconnect modifications rework',
#   'colo-1 cell-4 mer-ups battery disconnect modifications rework',
#   'csa punchlist - colo-1',
#   '6.1-88 colo-1 mer awaiting updated ups l3 test script approval',
#   '6.1-89 rfi574- colo-1 relocating msb epms device to different cabinet',
#   '6.1-92 colo-1 sf/ rf startup delay (vendor schedule availability)',
#   '6.1-93 colo-1 hvac minisplits startup delay (vendor schedule availability)',
#   "6.1-95 colo-1 ats's l3 startup delay (vendor schedule availability)",
#   '6.1-96 colo-1 pdu - epms l3 startup delay (vendor schedule availability)',
#   'mep punchlist - colo-1',
#   'ae/owner punchlist - colo-1',
#   '6.1-98 admin/colo-1 asco epms connectivity issues',
#   "6.1-88  admin/ colo-1 mer/admin ups l3 testing (includes shutdown to move pqm's & pqm data post proccessing)",
#   '6.1-106 colo-1 cell-2 ups01 power module failure'],
#  'admin/colo-1': ['admin/colo-1 network startup',
#   'admin/colo-1 bim signoff',
#   'linx mobilization to admin/colo-1',
#   '6.1-98 admin/colo-1 asco epms connectivity issues'],
#  'structure': ['site temp power procurement & infrastructure',
#   'term- jaz  to structure- (incl stress cones) from ums',
#   'start superstructure',
#   'start superstructure',
#   'start superstructure',
#   'start superstructure'],
#  'l2': ['l2 - cx',
#   'security commissioning (level2 with corp net after ist)',
#   'security commissioning (level2 with corp net after ist)',
#   'security commissioning (level2 with corp net after ist)',
#   'security commissioning (level2 with corp net after ist)',
#   'l2 cx complete (yellow tag)',
#   'l2 cx complete (yellow tag)',
#   'l2 cx complete (yellow tag)',
#   'l2 cx complete (yellow tag)',
#   'start of l2 cx',
#   'start of l2 cx',
#   'start of l2 cx',
#   'start of l2 cx',
#   'colo1 cell2 mer security/telecom missing raceway installation',
#   'colo-1 cell2 rearrange roxtec blocks per coordination layout',
#   'colo1 cell2 interior mer conduit installation utility side',
#   'colo-1 cell2 interior mer conduit installation building side',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   'se- completed l2 qc checklist',
#   '6.1.26.1 l2/l3 scripts se mer overall script',
#   '6.1.26.2 l2/l3 scripts siemens bas sat scripts',
#   'colo-2 cell2 rearrange roxtec blocks per coordination layout (delete)',
#   'colo2 cell2 interior mer conduit installation utility side(delete)',
#   'colo-2 cell2 interior mer conduit installation building (delete)',
#   'colo2 cell2 mer security/telecom missing raceway installation'],
#  'l3': ['l3 - cx',
#   'l3 cx start',
#   'l3 cx complete (green tag)',
#   'l3 cx start',
#   'l3 cx complete (green tag)',
#   'l3 cx start',
#   'l3 cx complete (green tag)',
#   'l3 cx start',
#   'l3 cx complete (green tag)',
#   'colo1 cell3 mer security/telecom missing raceway installation',
#   'colo-1 cell3 rearrange roxtec blocks per coordination layout',
#   'colo1 cell3 interior mer conduit installation utility side',
#   'colo-1 cell3 interior mer conduit installation building side',
#   '6.1.26.1 l2/l3 scripts se mer overall script',
#   '6.1.26.2 l2/l3 scripts siemens bas sat scripts',
#   'colo-2 cell3 rearrange roxtec blocks per coordination layout',
#   'colo2 cell3 interior mer conduit installation utility side',
#   'colo-2 cell3 interior mer conduit installation building side',
#   'colo2 cell3 mer security/telecom missing raceway installation',
#   '6.1.63- colo1-ups01-pnl01 compass issues constraining l3o?=s',
#   'security commissioning (level3 dcps)',
#   'security commissioning (level3 dcps)',
#   'security commissioning (level3 dcps)',
#   'security commissioning (level3 dcps)',
#   '6.1-88 colo-1 mer awaiting updated ups l3 test script approval',
#   "6.1-95 colo-1 ats's l3 startup delay (vendor schedule availability)",
#   '6.1-96 colo-1 pdu - epms l3 startup delay (vendor schedule availability)',
#   "6.1-88  admin/ colo-1 mer/admin ups l3 testing (includes shutdown to move pqm's & pqm data post proccessing)"],
#  'mer': ['delay #9 mer delivery delay',
#   'delay#15 wa state l&i mer onsite inspection delay due to covid-19',
#   'delay#16 nopc-8 se - missing mer raceways',
#   'delay#17 nopc-9 se - mer roxtec raceway fixes',
#   'delay#18 nopc-10 se - mer flex conduit code & specification violation',
#   'delay#21 nopc-12 se field install mer batteries delay',
#   'delay#23 nopc-14 mer set safety delay',
#   'delay#35- nopc-23 - rfi548- mer-contractor g battery disconnect modifications',
#   'delay#36- nopc-21 colo-3 & 4 mer cable bus access space constraint',
#   'delay#37- nopc-24 colo-3 mer raceway constraints',
#   'delay#38 nopc-25 colo-4 mer raceway constraints',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'pull / term / test conductors ( mer to pdu)',
#   'assemble mer & complete shipping split (se)',
#   'msft delivery -mer roj colo 1 cell 1 (11/6/20)',
#   'ready to set exterior mer',
#   'ready to set mer',
#   'ready to set exterior mer',
#   'ready to set exterior mer',
#   'msft delivery -mer roj colo 1 cell 3 (11/20/20)',
#   'msft delivery -mer roj colo 1 cell 2 (11/13/20)',
#   'msft delivery -mer roj colo 1 cell 4 (11/30/20)',
#   'msft delivery -mer roj colo 2 cell 1 (12/15/20)',
#   'msft delivery -mer roj colo 2 cell 2 (12/22/20)',
#   'msft delivery -mer roj colo 2 cell 3 (12/28/20)',
#   'msft delivery -mer roj colo 2 cell 4 (1/5/20)',
#   'msft delivery -mer roj colo 3 cell 1 (1/29/21)',
#   'msft delivery -mer roj colo 3 cell 3 (2/12/21)',
#   'msft delivery -mer roj colo 3 cell 2 (2/5/21)',
#   'msft delivery -mer roj colo 3 cell 4 (2/19/21)',
#   'msft delivery -mer roj colo 4 cell 1 (3/12/21)',
#   'msft delivery -mer roj colo 4 cell 3 (3/26/21)',
#   'msft delivery -mer roj colo 4 cell 2 (3/19/21)',
#   'msft delivery -mer roj colo 4 cell 4 (4/2/21)',
#   'pad ready for mer colo-2 cell-1',
#   'pad ready for mer colo-2 cell-3',
#   'pad ready for mer colo-2 cell-2',
#   'pad ready for mer colo-2 cell-4',
#   'pad ready for mer colo-3 cell-1',
#   'pad ready for mer colo-3 cell-3',
#   'pad ready for mer colo-3 cell-2',
#   'pad ready for mer colo-3 cell-4',
#   'pad ready for mer colo-4 cell-1',
#   'pad ready for mer colo-4 cell-3',
#   'pad ready for mer colo-4 cell-2',
# ...
#   'upm roj colo-1 cell-2',
#   'msft delivery -upm - roj - colo2- cell-2 (11/25/2020)',
#   'upm - roj - colo2- cell-2',
#   'upm - roj - colo3- cell-2',
#   'msft delivery -upm - roj - colo3- cell-2 (11/23/2020)',
#   'fluid cooler - roj colo -2 cell-2',
#   'msft delivery -fluid cooler - roj colo -2 cell-2',
#   'fluid cooler - roj colo -3 cell-2',
#   'msft delivery -fluid cooler - roj colo -3 cell-2',
#   'fluid cooler - roj colo -4 cell-2',
#   'msft delivery -fluid cooler - roj colo -4 cell-2',
#   'generator roj colo 1- cell-2',
#   'msft delivery -generator roj colo 1- cell-2',
#   'pdu roj colo-1 cell-2',
#   'msft delivery -pdu roj colo-1 cell-2',
#   'pdu roj colo-2 cell-2',
#   'msft delivery -pdu roj colo-2 cell-2',
#   'pdu roj colo-3 cell-2',
#   'msft delivery -pdu roj colo-3 cell-2',
#   'pdu roj colo-4 cell-2',
#   'msft delivery -pdu roj colo-4 cell-2',
#   'delay in upm delivery (duration = colo1 cell-2 psr(10/13) to msft delivery)',
#   'delay in colo-1- cell-2 mer delivery (duration = colo1 cell-2 psr(11/13/20) to msft delivery)',
#   'delay in colo-2- cell-2 mer delivery (duration = colo 2 cell-2 psr(12/22/20) to msft delivery)',
#   'delay in colo-3- cell-2 mer delivery (duration = colo-3 cell-2 psr(2/5/21) to msft delivery)',
#   'delay in colo-4- cell-2 mer delivery (duration = colo-4 cell-2 psr(3/19/21) to msft delivery)',
#   'delay in upm delivery (duration = colo2 cell-2 11/25 to msft delivery)',
#   'delay in upm delivery (duration = colo3 cell-2 11/23 to msft delivery)',
#   'delay in upm delivery (duration = colo4 cell-2 12/7 to msft delivery)',
#   'delay in colo-2 cell-2 generator (duration= colo-2 cell-2 psr(11/6/20) to msft delivery)',
#   'colo-1 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-2 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-4 cell-2 wa state l&i onsite checkup & approval to connect to mer',
#   'delay in colo-3 cell-2 generator (duration= colo-3 cell-2 psr(11/6/20) to msft delivery)',
#   'delay in colo-4 cell-2 generator (duration= colo-4 cell-2 psr(11/6/20) to msft delivery)',
#   'delay in colo-1 cell-2 generator (duration= colo-1 cell-2 psr(9/15/20) to msft delivery)',
#   'colo-1 cell-2 remove/ replace busway & hangers',
#   'colo-1 cell-2 mer flex conduit fixes',
#   'upm yellow tagging - colo-1 cell-2',
#   'upm yellow tagging - colo-2 cell-2',
#   'upm yellow tagging -colo-3 cell-2',
#   'upm yellow tagging -colo-4 cell-2',
#   'colo-1 cell-2 se install ups batteries in cabinet',
#   'colo-2 cell-2 awaiting se revised tool ""come along"" for mer lift & set',
#   '6.1.34.2 colo-1 cell-2 rework on ats input conductors',
#   'colo-2 cell-2 remove/ replace busway & hangers',
#   'colo-1 cell-2 field modification of tray',
#   'colo-2 cell-2 mer flex conduit fixes',
#   'colo-2 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-2 se install ups batteries in cabinet',
#   'colo-3 cell-2 se install ups batteries in cabinet',
#   'colo-4 cell-2 se install ups batteries in cabinet',
#   '6.1.01.2 mer 10a hrg retrofit colo-1 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-1 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-2 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-3 cell-2',
#   'neta test validation inpections- veca-eps-rts colo-4 cell-2',
#   '6.1.47- colo-1 cell-2 ups01- factory test thermal event',
#   'colo-1 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-2 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-3 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-4 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-2 cell-2 install missing raceway & bussing within generator',
#   'colo-3 cell-2 install missing raceway & bussing within generator',
#   'colo-4 cell-2 install missing raceway & bussing within generator',
#   'nopc-18 remove colo-1 cell-2 transformer',
#   'nopc-18 remove colo-2 cell-2 transformer',
#   'nopc-18 remove colo-4 cell-2 transformer',
#   'nopc-18 remove colo-3 cell-2 transformer',
#   '6.1.01.2 mer 10a hrg retrofit colo-2 cell-2',
#   '6.1.01.2 mer 10a hrg retrofit colo-3 cell-2',
#   '6.1.01.2 mer 10a hrg retrofit colo-4 cell-2',
#   'nopc-18 reinstall colo-1 cell-2 transformer',
#   'nopc-18 reinstall colo-2 cell-2 transformer',
#   'nopc-18 reinstall colo-3 cell-2 transformer',
#   'nopc-18 reinstall colo-4 cell-2 transformer',
#   'colo-1 cell-2 mer-ups battery disconnect modifications rework',
#   'colo-2 cell-2 mer-ups battery disconnect modifications rework',
#   'colo-3 cell-2 mer-ups battery disconnect modifications rework',
#   'colo-4 cell-2 mer-ups battery disconnect modifications rework',
#   'colo-4 cell-2 remove inaccessible tray in mer',
#   'colo-4 cell-2 reinstall tray in mer',
#   'colo-3 cell-2 remove inaccessible tray in mer',
#   'colo-3 cell-2 reinstall tray in mer',
#   'colo-4 cell-2 conduit rework',
#   'colo-2 cell-2 ups pnl01 compass issues preventing cyt',
#   '6.1-106 colo-1 cell-2 ups01 power module failure',
#   'colo-2 cell-2 open issues preventing yellow tags mer equipment'],
#  'cell-4': ['colo-1 cell-4',
#   'colo-2 cell-4',
#   'colo-3 cell-4',
#   'colo-4 cell-4',
#   'pad ready for mer colo-2 cell-4',
#   'pad ready for mer colo-3 cell-4',
#   'pad ready for mer colo-4 cell-4',
#   'pad ready for mer colo-1 cell-4',
#   'pull cross overs- colo-1 cell-3 to cell-4',
#   'pull cross overs- colo-2 cell-3 to cell-4',
#   'pull cross overs- colo-3 cell-3 to cell-4',
#   'pull cross overs- colo-4 cell-3 to cell-4',
#   'upm roj colo-1 cell-4',
#   'msft delivery -upm roj colo-1 cell-4 (psr roj -10/28/2020)',
#   'upm - roj - colo2- cell-4',
#   'msft delivery -upm - roj - colo2- cell-4 (11/25/2020)',
#   'upm - roj - colo3- cell-4',
#   'msft delivery -upm - roj - colo3- cell-4 (11/23/2020)',
#   'msft delivery -fluid cooler - roj colo -3 cell-4',
#   'fluid cooler - roj colo -3 cell-4',
#   'fluid cooler - roj colo -4 cell-4',
#   'msft delivery -fluid cooler - roj colo -4 cell-4',
#   'generator roj colo 1- cell-4',
#   'msft delivery -generator roj colo 1- cell-4',
#   'pdu roj colo-1 cell-4',
#   'msft delivery -pdu roj colo-1 cell-4',
#   'pdu roj colo-2 cell-4',
#   'msft delivery -pdu roj colo-2 cell-4',
#   'pdu roj colo-3 cell-4',
#   'msft delivery -pdu roj colo-3 cell-4',
#   'pdu roj colo-4 cell-4',
#   'msft delivery -pdu roj colo-4 cell-4',
#   'term colo -1 cell-4 upm',
#   'term colo -2  cell-4 upm',
#   'term colo -3  cell-4 upm',
#   'term colo -4  cell-4 upm',
#   'term colo -1 cell-4 upm',
#   'term colo -2 cell-4 upm',
#   'term colo -3 cell-4 upm',
#   'term colo -4 cell-4 upm',
#   'delay in upm delivery (duration = colo1 cell-4 psr (10/28) to msft delivery)',
#   'delay in colo-1- cell-4 mer delivery (duration = colo1 cell-4 psr(11/30/20) to msft delivery)',
#   'delay in colo-2- cell-4 mer delivery (duration = colo 2- cell-4 psr(1/5/21) to msft delivery)',
#   'delay in colo-3 cell-4 mer delivery (duration = colo-3 cell-4 psr(2/19/21) to msft delivery)',
#   'delay in colo-4- cell-4 mer delivery (duration = colo-4 cell-4 psr(4/2/21) to msft delivery)',
#   'delay in upm delivery (duration = colo2 cell-4 11/25 to msft delivery)',
#   'delay in upm delivery (duration = colo3 cell-4 11/23 to msft delivery)',
#   'delay in upm delivery (duration = colo4 cell-4 12/18 to msft delivery)',
#   'delay in colo-2 cell-4 generator (duration= colo-2 cell-4 psr(11/21/20) to msft delivery)',
#   'colo-1 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-2 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-3 cell-4 wa state l&i onsite inspection & approval to connect to mer',
#   'colo-4 cell-4 wa state l&i onsite checkup & approval to connect to mer',
#   'delay in colo-3 cell-4 generator (duration= colo-3 cell-4 psr(11/21/20) to msft delivery)',
#   'delay in colo-4 cell-4 generator (duration= colo-4 cell-4 psr(11/21/20) to msft delivery)',
#   'delay in colo-1 cell-4 generator (duration= colo-1 cell-4 psr(9/29/20) to msft delivery)',
#   'colo-1 cell-4 remove/ replace busway & hangers',
#   'colo-1 cell-4 mer flex conduit fixes',
#   'upm yellow tagging - colo-1 cell-4',
#   'upm yellow tagging -colo-2 cell-4',
#   'upm yellow tagging colo-3 cell-4',
#   'upm yellow tagging -colo-4 cell-4',
#   'colo-1 cell-4 se install ups batteries in cabinet',
#   '6.1.34.4 colo-1 cell-4 rework on ats input conductors',
#   'colo-2 cell-4 rearrange roxtec blocks per coordination layout',
#   'colo-2 cell-4 mer flex conduit fixes',
#   'colo-2 cell-4 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-4 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-4 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-4 se install ups batteries in cabinet',
#   'colo-3 cell-4 se install ups batteries in cabinet',
#   'colo-4 cell-4 se install ups batteries in cabinet',
#   '6.1.01.4 mer 10a hrg retrofit colo-1 cell-4',
#   'neta test validation inpections- veca-eps-rts colo-1 cell-4',
#   'neta test validation inpections- veca-eps-rts colo-2 cell-4',
#   'neta test validation inpections- veca-eps-rts colo-3 cell-4',
#   'neta test validation inpections- veca-eps-rts colo-4 cell-4',
#   'colo-1 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-2 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-3 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-4 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)',
#   'colo-2 cell-4 install missing raceway & bussing within generator',
#   'colo-3 cell-4 install missing raceway & bussing within generator',
#   'colo-4 cell-4 install missing raceway & bussing within generator',
#   '6.2.03- replace damaged upm in colo-4 cell-4',
#   'nopc-18 remove colo-1 cell-4 transformer',
#   'nopc-18 remove colo-2 cell-4 transformer',
#   'nopc-18 remove colo-4 cell-4 transformer',
#   'nopc-18 remove colo-3 cell-4 transformer',
#   '6.1.01.4 mer 10a hrg retrofit colo-2 cell-4',
#   '6.1.01.4 mer 10a hrg retrofit colo-3 cell-4',
#   '6.1.01.4 mer 10a hrg retrofit colo-4 cell-4',
#   'nopc-18 reinstall colo-1 cell-4 transformer',
#   'nopc-18 reinstall colo-2 cell-4 transformer',
#   'nopc-18 reinstall colo-3 cell-4 transformer',
#   'nopc-18 reinstall colo-4 cell-4 transformer',
#   'colo-1 cell-4 mer-ups battery disconnect modifications rework',
#   'colo-2 cell-4 mer-ups battery disconnect modifications rework',
#   'colo-3 cell-4 mer-ups battery disconnect modifications rework',
#   'colo-4 cell-4 mer-ups battery disconnect modifications rework',
#   'colo-3 cell-4 remove inaccessible tray in mer',
#   'colo-3 cell-4 reinstall tray in mer',
#   'colo-4 cell-4 remove inaccessible tray in mer4',
#   'colo-4 cell-4 reinstall tray in mer',
#   'colo-4 cell-4 conduit rework',
#   'colo-2 cell-4 ups pnl01 compass issues preventing cyt',
#   'colo-2 cell-4 open issues preventing yellow tags mer equipment'],
#  'jaz': ['mv ductbanks procurement drb#1 jaz to ums/urs & upm to ums',
#   'mv wire procurement drb#1 jaz to ums/urs & upm to ums',
#   'drb#1 bim modeling & coordination drb#1 jaz to ums/urs & upm to ums',
#   'site- neher mcgrath study drb#1 jaz to ums/urs & upm to ums',
#   'jaz riser support drb#1 procurement/ jaz foundations/construction',
#   'vault- set vault along  urs to jaz run',
#   'duct bank - urs to vault  - urs to jaz run',
#   'duct bank - vault to jaz - urs to jaz run',
#   'vault- set vault along ums to jaz run',
#   'duct bank - jaz to vault- ums to jaz run',
#   'duct bank - vault to ums- ums to jaz run',
#   'pull - jaz to urs',
#   'pull - jaz to ums',
#   'term- jaz  to structure- (incl stress cones) from ums'],
#  'fiber': ['install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'install/dress/test production fiber (includes mor rack set & fiber runner)',
#   'telecom-rng fiber underground installation',
#   'telecom-rng fiber cnr buildout'],
#  'building': ['duct bank- building to urs - 1st half',
#   'duct bank- building to urs(upto horse shoe) - 2nd half',
#   'duct bank - building to north vault urs run',
#   'sure steel (building, mezz, ceiling) - create punch list',
#   'sure steel (building, mezz, ceiling) - complete punch list',
#   'colo-1 cell-1 interior mer conduit installation building side complete march1st (mer discovery corrections & signoff)',
#   'colo-1 cell3 interior mer conduit installation building side',
#   'colo-1 cell2 interior mer conduit installation building side',
#   'colo-1 cell4 interior mer conduit installation building side',
#   'colo-2 cell-1 interior mer conduit installation building side',
#   'colo-2 cell3 interior mer conduit installation building side',
#   'colo-2 cell2 interior mer conduit installation building (delete)',
#   'colo2 cell4 interior mer conduit installation building side',
#   'complete building footprint pad ready   (clayco- nic)',
#   'complete building footprint pad ready  (clayco- nic)',
#   'complete building footprint pad ready ',
#   'complete building footprint pad ready  (clayco- nic)'],
#  'west': ['west elevation',
#   'west elevation',
#   'west short runs',
#   'west upms',
#   'west elevation',
#   'west elevation',
#   'exterior insulated metal panels installation - west elevation',
#   'duct bank - north crossover  (urs to west vault run)',
#   'duct bank - south cross over  (urs to west vault run)'],
#  'east': ['east elevation',
#   'east elevation',
#   'east short runs',
#   'east upms',
#   'east elevation',
#   'east elevation',
#   'exterior insulated metal panels installation - east elevation'],
#  'mobilization': ['linx mobilization to admin/colo-1',
#   'start mobilization',
#   'start mobilization',
#   'start mobilization',
#   'start mobilization'],
#  '`': [],
#  'rfi#432': ['colo-2 cell-1 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-3 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-2 cell-4 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-1 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-3 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-3 cell-4 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-1 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-3 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-2 install tube steel & cable tray transition per rfi#432',
#   'colo-4 cell-4 install tube steel & cable tray transition per rfi#432']}

# %%
#stores clusters in json file
import json
with open('cluster.json', 'w') as f:
    json.dump(name_clusters, f)

# %%
name_clusters['construction']
# Out:
# ['construction summary',
#  'bas prefunctional testing on construction server',
#  'bas prefunctional testing on construction server',
#  'bas prefunctional testing on construction server',
#  'bas prefunctional testing on construction server',
#  'jaz riser support drb#1 procurement/ jaz foundations/construction',
#  'construction server- colo-1',
#  'construction server- colo-2',
#  'construction server- colo-3',
#  'construction server- colo-4',
#  'all construction activities -safety standown due to admin gen unplanned energization']

# %%
## FINAL STEP - Add to original
items = { 1:2 }
1 in items
# Out:
# True

# %%
def map_cluster_to_cluster_name(name_clusters):
    index = 1;
    output = dict()
    for key in name_clusters.keys():
        values = name_clusters[key]
        values.append(key)
        prefix = "Cluster#{}"
        cluster_name = prefix.format(index)

        for v in values:
            output[v] = cluster_name
        index += 1
    print(index)
    return output

# %%
map_cluster_to_cluster_name(name_clusters)
# Out:
# 55
# {'construction summary': 'Cluster#1',
#  'bas prefunctional testing on construction server': 'Cluster#33',
#  'jaz riser support drb#1 procurement/ jaz foundations/construction': 'Cluster#47',
#  'construction server- colo-1': 'Cluster#33',
#  'construction server- colo-2': 'Cluster#33',
#  'construction server- colo-3': 'Cluster#33',
#  'construction server- colo-4': 'Cluster#33',
#  'all construction activities -safety standown due to admin gen unplanned energization': 'Cluster#19',
#  'construction': 'Cluster#1',
#  'preconstruction': 'Cluster#2',
#  'executed delays (co-66)': 'Cluster#3',
#  'pending delays': 'Cluster#3',
#  'delay #1 late submittal approval': 'Cluster#3',
#  'delay #3 fluid cooler': 'Cluster#3',
#  'delay #2 late upm deliveries': 'Cluster#29',
#  'delay #4 drb#2': 'Cluster#3',
#  'delay #5 water treatment skids delay': 'Cluster#3',
#  'delay #6 drb#3': 'Cluster#3',
#  'delay #7- force majeure shutdown -hazardous air quality index': 'Cluster#3',
#  'delay #8-underground utilities impacted by overhead power lines': 'Cluster#3',
#  'delay #9 mer delivery delay': 'Cluster#25',
#  'delay#10 covid procurement delay': 'Cluster#32',
#  'delay#11 mwh02- telecom vault tie-in msow delay': 'Cluster#3',
#  'delay#12 late ums delivery delay': 'Cluster#3',
#  'delay#13 gen delivery delay': 'Cluster#3',
#  'delay#14 weather': 'Cluster#3',
#  'delay#15 wa state l&i mer onsite inspection delay due to covid-19': 'Cluster#25',
#  'delay#16 nopc-8 se - missing mer raceways': 'Cluster#33',
#  'delay#17 nopc-9 se - mer roxtec raceway fixes': 'Cluster#33',
#  'delay#18 nopc-10 se - mer flex conduit code & specification violation': 'Cluster#33',
#  'delay#19 nopc-11 failed starline busway hangers': 'Cluster#3',
#  'delay#20 admin gen missing bussing': 'Cluster#19',
#  'delay#21 nopc-12 se field install mer batteries delay': 'Cluster#33',
#  'delay#22 nopc-13 february 2021 cx constraints': 'Cluster#3',
#  'delay#23 nopc-14 mer set safety delay': 'Cluster#33',
#  'delay#24 nopc-15 gen cable bus opening dimension bust': 'Cluster#3',
#  'delay#25 veca safety standown due to admin gen unplanned enegization': 'Cluster#19',
#  'delay#26 field modification of tray above msb': 'Cluster#3',
#  'delay#28 nopc-17 march 2021 cx constraints': 'Cluster#3',
#  'delay#27 nopc-16 missing wireway in colos 2-4 generators': 'Cluster#30',
#  'delay#31 nopc-20 april 2021 cx constraints': 'Cluster#3',
#  'delay#29 nopc-18 msb01 pdu feeder breaker safety space constraint': 'Cluster#31',
#  'delay#30 nopc-19 covid-19 electrician quarantine constraint': 'Cluster#3',
#  'delay#32 missing admin arc flash labels (rfi-520)': 'Cluster#19',
#  'delay#33 nopc-22 may 2021 cx constraints': 'Cluster#3',
#  'delay#34 site stand-down (diversity training)': 'Cluster#4',
#  'delay#35- nopc-23 - rfi548- mer-contractor g battery disconnect modifications': 'Cluster#25',
#  'delay#36- nopc-21 colo-3 & 4 mer cable bus access space constraint': 'Cluster#25',
#  'delay#37- nopc-24 colo-3 mer raceway constraints': 'Cluster#25',
#  'delay#38 nopc-25 colo-4 mer raceway constraints': 'Cluster#25',
#  'delay#39 nopc-26 july cx constraints': 'Cluster#3',
#  'delay#40  contractor g pnl01 issues': 'Cluster#3',
#  'delay #41 nopc-27 aug  cx constraints': 'Cluster#3',
#  'delay#22.1 contractor a february 2021 cx constraints': 'Cluster#3',
#  'delay#22.2 contractor d february 2021 cx constraints': 'Cluster#3',
#  'delay#22.3 contractor c february 2021 cx constraints': 'Cluster#3',
#  'delay#22.4 contractor b february 2021 cx constraints': 'Cluster#3',
#  'delay#28.1 contractor a': 'Cluster#3',
#  'delay#28.2 contractor d': 'Cluster#3',
#  'delay#28.3 contractor c february': 'Cluster#3',
#  'delay#28.4 contractor b': 'Cluster#3',
#  'delay#31.1 contractor a': 'Cluster#3',
#  'delay#31.2 contractor d': 'Cluster#3',
#  'delay#31.3 contractor c february': 'Cluster#3',
#  'delay#31.4 contractor b': 'Cluster#3',
#  'delay#31.5 contractor e': 'Cluster#3',
#  'delay#31.6 bac': 'Cluster#3',
#  'delay#33.1 contractor a': 'Cluster#3',
#  'delay#33.2 contractor d': 'Cluster#3',
#  'delay#33.3 contractor c february': 'Cluster#3',
#  'delay#33.4 contractor b': 'Cluster#3',
#  'delay#33.5 contractor e': 'Cluster#3',
#  'delay#33.6 bac': 'Cluster#3',
#  'delay#39.1 contractor a': 'Cluster#3',
#  'delay#39.2 contractor f': 'Cluster#3',
#  'delay#39.3 contractor a1': 'Cluster#3',
#  'weather (5 days) - 3 remaining check delay #14 for updates': 'Cluster#3',
#  'weather (5 days) - 0 remaining check delay #14 for updates': 'Cluster#3',
#  'delay in upm delivery (duration = colo1 cell-1 psr (9/19) to msft delivery)': 'Cluster#43',
#  'delay in colo-1- cell-1 mer delivery (duration = colo1 cell-1 psr(11/6/20) to msft delivery)': 'Cluster#43',
#  'delay in upm delivery (duration = colo1 cell-2 psr(10/13) to msft delivery)': 'Cluster#45',
#  'delay in upm delivery (duration = colo1 cell-3 psr(9/28) to msft delivery)': 'Cluster#44',
#  'delay in upm delivery (duration = colo1 cell-4 psr (10/28) to msft delivery)': 'Cluster#46',
#  'delay in colo-1- cell-2 mer delivery (duration = colo1 cell-2 psr(11/13/20) to msft delivery)': 'Cluster#45',
#  'delay in colo-1- cell-3 mer delivery (duration = colo1 cell-3 psr(11/20/20) to msft delivery)': 'Cluster#44',
#  'delay in colo-2- cell-1 mer delivery (duration = colo1 cell-1 psr(12/15/20) to msft delivery)': 'Cluster#43',
#  'delay in colo-2- cell-2 mer delivery (duration = colo 2 cell-2 psr(12/22/20) to msft delivery)': 'Cluster#45',
#  'delay in colo-2- cell-3 mer delivery (duration = colo 2- cell-3 psr(12/28/20) to msft delivery)': 'Cluster#44',
#  'delay in colo-3- cell-1 mer delivery (duration = colo-3 cell-1 psr(1/29/21) to msft delivery)': 'Cluster#43',
#  'delay in colo-3- cell-2 mer delivery (duration = colo-3 cell-2 psr(2/5/21) to msft delivery)': 'Cluster#45',
#  'delay in colo-3 cell-3 mer delivery (duration = colo-3 cell-3 psr(2/12/21) to msft delivery)': 'Cluster#44',
#  'delay in colo-4- cell-1 mer delivery (duration= colo-4 cell-1 psr(3/12/21) to msft delivery)': 'Cluster#43',
#  'delay in colo-4- cell-2 mer delivery (duration = colo-4 cell-2 psr(3/19/21) to msft delivery)': 'Cluster#45',
#  'delay in colo-4- cell-3 mer delivery (duration = colo-4 cell-3 psr(3/26/21) to msft delivery)': 'Cluster#44',
#  'delay in colo-1- cell-4 mer delivery (duration = colo1 cell-4 psr(11/30/20) to msft delivery)': 'Cluster#46',
#  'delay in colo-2- cell-4 mer delivery (duration = colo 2- cell-4 psr(1/5/21) to msft delivery)': 'Cluster#46',
#  'delay in colo-3 cell-4 mer delivery (duration = colo-3 cell-4 psr(2/19/21) to msft delivery)': 'Cluster#46',
#  'delay in colo-4- cell-4 mer delivery (duration = colo-4 cell-4 psr(4/2/21) to msft delivery)': 'Cluster#46',
#  'wire mesh procurement delay': 'Cluster#32',
#  'delay in upm delivery (duration = colo2 cell-1 11/25 to msft delivery)': 'Cluster#43',
#  'delay in upm delivery (duration = colo2 cell-2 11/25 to msft delivery)': 'Cluster#45',
#  'delay in upm delivery (duration = colo2 cell-3 11/25 to msft delivery)': 'Cluster#44',
#  'delay in upm delivery (duration = colo2 cell-4 11/25 to msft delivery)': 'Cluster#46',
#  'delay in upm delivery (duration = colo3 cell-1 psr 11/23 to msft delivery)': 'Cluster#43',
#  'delay in upm delivery (duration = colo3 cell-2 11/23 to msft delivery)': 'Cluster#45',
#  'delay in upm delivery (duration = colo3 cell-3 11/23 to msft delivery)': 'Cluster#44',
#  'delay in upm delivery (duration = colo3 cell-4 11/23 to msft delivery)': 'Cluster#46',
#  'delay in upm delivery (duration = colo4 cell-1 12/7 to msft delivery)': 'Cluster#43',
#  'delay in upm delivery (duration = colo4 cell-2 12/7 to msft delivery)': 'Cluster#45',
#  'delay in upm delivery (duration = colo4 cell-3 12/18 to msft delivery)': 'Cluster#44',
#  'delay in upm delivery (duration = colo4 cell-4 12/18 to msft delivery)': 'Cluster#46',
#  'delay in ums delivery (duration =  (9/19) to msft delivery)': 'Cluster#3',
#  'delay in colo-2 cell-1 generator (duration= colo-2 cell-1 psr(10/12/20) to msft delivery)': 'Cluster#43',
#  'delay in colo-2 cell-2 generator (duration= colo-2 cell-2 psr(11/6/20) to msft delivery)': 'Cluster#45',
#  'delay in colo-2 cell-4 generator (duration= colo-2 cell-4 psr(11/21/20) to msft delivery)': 'Cluster#46',
#  'delay in colo-2 cell-3 generator (duration= colo-2 cell-3 psr(10/22/20) to msft delivery)': 'Cluster#44',
#  'delay in colo-3 cell-1 generator (duration= colo-3 cell-1 psr(10/12/20) to msft delivery)': 'Cluster#43',
#  'delay in colo-3 cell-2 generator (duration= colo-3 cell-2 psr(11/6/20) to msft delivery)': 'Cluster#45',
#  'delay in colo-3 cell-4 generator (duration= colo-3 cell-4 psr(11/21/20) to msft delivery)': 'Cluster#46',
#  'delay in colo-3 cell-3 generator (duration= colo-3 cell-3 psr(10/22/20) to msft delivery)': 'Cluster#44',
#  'delay in colo-4 cell-1 generator (duration= colo-4 cell-1 psr(10/12/20) to msft delivery)': 'Cluster#43',
#  'delay in colo-4 cell-2 generator (duration= colo-4 cell-2 psr(11/6/20) to msft delivery)': 'Cluster#45',
#  'delay in colo-4 cell-4 generator (duration= colo-4 cell-4 psr(11/21/20) to msft delivery)': 'Cluster#46',
#  'delay in colo-4 cell-3 generator (duration= colo-4 cell-3 psr(10/22/20) to msft delivery)': 'Cluster#44',
#  'delay in colo-1 cell-1 generator (duration= colo-1 cell-1 psr(9/15/20) to msft delivery)': 'Cluster#43',
#  'delay in colo-1 cell-2 generator (duration= colo-1 cell-2 psr(9/15/20) to msft delivery)': 'Cluster#45',
#  'delay in colo-1 cell-4 generator (duration= colo-1 cell-4 psr(9/29/20) to msft delivery)': 'Cluster#46',
#  'delay in colo-1 cell-3 generator (duration= colo-1 cell-3 psr(9/29/20) to msft delivery)': 'Cluster#44',
#  '6.1-92 colo-1 sf/ rf startup delay (vendor schedule availability)': 'Cluster#20',
#  '6.1-93 colo-1 hvac minisplits startup delay (vendor schedule availability)': 'Cluster#20',
#  "6.1-95 colo-1 ats's l3 startup delay (vendor schedule availability)": 'Cluster#24',
#  '6.1-96 colo-1 pdu - epms l3 startup delay (vendor schedule availability)': 'Cluster#31',
#  'colo-3 delay in se uploading qc checkilst': 'Cluster#33',
#  'delay': 'Cluster#3',
#  'telecom-communications site loop/ductbank': 'Cluster#4',
#  'site water / fire loop': 'Cluster#4',
#  'site storm': 'Cluster#4',
#  'site sanitary': 'Cluster#4',
#  'landscape and site specialties': 'Cluster#4',
#  'site lighting': 'Cluster#4',
#  'mobilize on site': 'Cluster#4',
#  'site temp power procurement & infrastructure': 'Cluster#32',
#  'off-site bim modeling & coordination': 'Cluster#4',
#  'site work complete': 'Cluster#4',
#  'site- neher mcgrath study drb#1 jaz to ums/urs & upm to ums': 'Cluster#47',
#  'remaining site sanitary': 'Cluster#4',
#  'site shut down - 9/9/2020': 'Cluster#4',
#  'site shut down - 9/10/2020': 'Cluster#4',
#  'site shut down - 9/11/2020': 'Cluster#4',
#  'site shut down - 9/12/2020': 'Cluster#4',
#  'site shut down - 9/14/2020': 'Cluster#4',
#  'site shut down - 9/15/2020': 'Cluster#4',
#  'site shut down - 9/16/2020': 'Cluster#4',
#  'colo-1 cell-1 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#43',
#  'colo-1 cell-3 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#44',
#  'colo-1 cell-2 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#45',
#  'colo-1 cell-4 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#46',
#  'colo-2 cell-1 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#43',
#  'colo-2 cell-3 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#44',
#  'colo-2 cell-2 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#45',
#  'colo-2 cell-4 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#46',
#  'colo-3 cell-1 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#43',
#  'colo-3 cell-3 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#44',
#  'colo-3 cell-2 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#45',
#  'colo-3 cell-4 wa state l&i onsite inspection & approval to connect to mer': 'Cluster#46',
#  'colo-4 cell-1 wa state l&i onsite checkup & approval to connect to mer': 'Cluster#43',
#  'colo-4 cell-3 wa state l&i onsite checkup & approval to connect to mer': 'Cluster#44',
#  'colo-4 cell-2 wa state l&i onsite checkup & approval to connect to mer': 'Cluster#45',
#  'colo-4 cell-4 wa state l&i onsite checkup & approval to connect to mer': 'Cluster#46',
#  '6.1.46- site upm inspections': 'Cluster#29',
#  'site': 'Cluster#4',
#  'general': 'Cluster#5',
#  'mdc1 admin/colo1 - lv3 cx complete (co-66: 20-aug-21)': 'Cluster#19',
#  'mdc1 admin/colo1 - fitout summary': 'Cluster#19',
#  'admin/colo1': 'Cluster#6',
#  'colo 2 fitout': 'Cluster#7',
#  'colo 3 fitout': 'Cluster#7',
#  'colo 4 fitout': 'Cluster#7',
#  'mdc1 colo2 - fitout summary': 'Cluster#7',
#  'mdc1 colo3 - fitout summary': 'Cluster#7',
#  'mdc1 colo4 - fitout summary': 'Cluster#7',
#  'fitout': 'Cluster#7',
#  'security commissioning (level2 with corp net after ist)': 'Cluster#33',
#  'security commissioning (level3 dcps)': 'Cluster#33',
#  'commissioning': 'Cluster#8',
#  'colo-2 cx': 'Cluster#9',
#  'colo-2 cell-1': 'Cluster#43',
#  'colo-2 cell-3': 'Cluster#44',
#  'colo-2 cell-2': 'Cluster#45',
#  'colo-2 cell-4': 'Cluster#46',
#  'colo-2 adp01 & adp02 equipment shift': 'Cluster#9',
#  'level 3 cx- colo-2': 'Cluster#9',
#  'pad ready for mer colo-2 cell-1': 'Cluster#43',
#  'pad ready for mer colo-2 cell-3': 'Cluster#44',
#  'pad ready for mer colo-2 cell-2': 'Cluster#45',
#  'pad ready for mer colo-2 cell-4': 'Cluster#46',
#  'duct bank- colo-2 upm to north valut': 'Cluster#29',
#  'vault- set 2nd vault along ums duct run near colo-2': 'Cluster#33',
#  'duct bank colo-2 upm to vault': 'Cluster#29',
#  'pull cross overs- colo-2 cell-3 to cell-4': 'Cluster#46',
#  'pul upm to upm colo-2- cell-1 to cell-3': 'Cluster#44',
#  'pull upm to upm colo-2 cell 2- cell - 4': 'Cluster#29',
#  'pull- urs to colo-2': 'Cluster#9',
#  'ahu - roj colo-2 cell- 1': 'Cluster#28',
#  'msft delivery -ahu - roj colo-2 cell- 3': 'Cluster#28',
#  'ahu - roj colo-2 cell- 2': 'Cluster#28',
#  'ahu - roj colo-2 cell- 4': 'Cluster#28',
#  'msft delivery -ahu - roj colo-2 cell- 1': 'Cluster#28',
#  'ahu - roj colo-2 cell- 3': 'Cluster#28',
#  'msft delivery -ahu - roj colo-2 cell- 2': 'Cluster#28',
#  'msft delivery -ahu - roj colo-2 cell- 4': 'Cluster#28',
#  'pdu roj colo-2 cell-1': 'Cluster#43',
#  'msft delivery -pdu roj colo-2 cell-1': 'Cluster#43',
#  'pdu roj colo-2 cell-3': 'Cluster#44',
#  'msft delivery -pdu roj colo-2 cell-3': 'Cluster#44',
#  'pdu roj colo-2 cell-2': 'Cluster#45',
#  'msft delivery -pdu roj colo-2 cell-2': 'Cluster#45',
#  'pdu roj colo-2 cell-4': 'Cluster#46',
#  'msft delivery -pdu roj colo-2 cell-4': 'Cluster#46',
#  'punch list colo-2': 'Cluster#9',
#  'msft delivery - colo-2,3,4 gen submittal approval': 'Cluster#9',
#  'set- colo-2 ums': 'Cluster#33',
#  'pad- colo-2 ums': 'Cluster#9',
#  'duct bank - ums02 to upm colo-2 cell-1': 'Cluster#43',
#  'pull- ums02- upm colo-2 cell-1': 'Cluster#43',
#  'ums - roj colo-2': 'Cluster#9',
#  "yellow tagging for colo-2 upm's": 'Cluster#29',
#  'upm yellow tagging -colo-2 cell-1': 'Cluster#43',
#  'upm yellow tagging -colo-2 cell-3': 'Cluster#44',
#  'upm yellow tagging - colo-2 cell-2': 'Cluster#45',
#  'upm yellow tagging -colo-2 cell-4': 'Cluster#46',
#  'colo-2 cell-2 awaiting se revised tool ""come along"" for mer lift & set': 'Cluster#45',
#  'colo-2 cell-1 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-2 cell-3 awaiting se revised tool ""come along"" for mer lift & set': 'Cluster#44',
#  '6.1.37- 6.2.01- ground fault setting on colo-2 gen mcb01': 'Cluster#33',
#  'colo-2 cell-1 remove/ replace busway & hangers': 'Cluster#43',
#  'colo-2 cell-2 remove/ replace busway & hangers': 'Cluster#45',
#  'colo-2 cell-1 rearrange roxtec blocks per coordination layout': 'Cluster#43',
#  'colo-2 cell-1 interior mer conduit installation building side': 'Cluster#49',
#  'colo-2 cell3 rearrange roxtec blocks per coordination layout': 'Cluster#24',
#  'colo-2 cell3 interior mer conduit installation building side': 'Cluster#49',
#  'colo-2 cell2 rearrange roxtec blocks per coordination layout (delete)': 'Cluster#23',
#  'colo-2 cell2 interior mer conduit installation building (delete)': 'Cluster#49',
#  'colo-2 cell-4 rearrange roxtec blocks per coordination layout': 'Cluster#46',
#  'colo-2 cell-1 mer flex conduit fixes': 'Cluster#43',
#  'colo-2 cell-3 mer flex conduit fixes': 'Cluster#44',
#  'colo-2 cell-2 mer flex conduit fixes': 'Cluster#45',
#  'colo-2 cell-4 mer flex conduit fixes': 'Cluster#46',
#  'colo-2 cell-3 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-2 cell-2 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-2 cell-4 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-2 cell-1 se install ups batteries in cabinet': 'Cluster#43',
#  'colo-2 cell-4 se install ups batteries in cabinet': 'Cluster#46',
#  'colo-2 cell-3 se install ups batteries in cabinet': 'Cluster#44',
#  'colo-2 cell-2 se install ups batteries in cabinet': 'Cluster#45',
#  'neta test validation inpections- veca-eps-rts colo-2 cell-1': 'Cluster#43',
#  'neta test validation inpections- veca-eps-rts colo-2 cell-3': 'Cluster#44',
#  'neta test validation inpections- veca-eps-rts colo-2 cell-2': 'Cluster#45',
#  'neta test validation inpections- veca-eps-rts colo-2 cell-4': 'Cluster#46',
#  'colo-2 cell-1 install missing raceway & bussing within generator': 'Cluster#43',
#  'colo-2 cell-1 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#43',
#  'colo-2 cell-3 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#44',
#  'colo-2 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#45',
#  'colo-2 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#46',
#  'colo-2 cell-2 install missing raceway & bussing within generator': 'Cluster#45',
#  'colo-2 cell-3 install missing raceway & bussing within generator': 'Cluster#44',
#  'colo-2 cell-4 install missing raceway & bussing within generator': 'Cluster#46',
#  'nopc-18 remove colo-2 cell-1 transformer': 'Cluster#43',
#  'nopc-18 remove colo-2 cell-2 transformer': 'Cluster#45',
#  'nopc-18 remove colo-2 cell-3 transformer': 'Cluster#44',
#  'nopc-18 remove colo-2 cell-4 transformer': 'Cluster#46',
#  '6.1.55-colo-2 - fc factoy re-wire (rfi-502)': 'Cluster#9',
#  '6.1.01.1 mer 10a hrg retrofit colo-2 cell-1': 'Cluster#43',
#  '6.1.01.4 mer 10a hrg retrofit colo-2 cell-4': 'Cluster#46',
#  '6.1.01.3 mer 10a hrg retrofit colo-2 cell-3': 'Cluster#44',
#  '6.1.01.2 mer 10a hrg retrofit colo-2 cell-2': 'Cluster#45',
#  'nopc-18 reinstall colo-2 cell-1 transformer': 'Cluster#43',
#  'nopc-18 reinstall colo-2 cell-2 transformer': 'Cluster#45',
#  'nopc-18 reinstall colo-2 cell-3 transformer': 'Cluster#44',
#  'nopc-18 reinstall colo-2 cell-4 transformer': 'Cluster#46',
#  'colo-2 cell-1 mer-ups battery disconnect modifications rework': 'Cluster#43',
#  'colo-2 cell-2 mer-ups battery disconnect modifications rework': 'Cluster#45',
#  'colo-2 cell-3 mer-ups battery disconnect modifications rework': 'Cluster#44',
#  'colo-2 cell-4 mer-ups battery disconnect modifications rework': 'Cluster#46',
#  '6.2-08 colo-2 cell- 1,2 mer equipment phenolic labelling': 'Cluster#25',
#  '6.2-08 colo-2 cell- 3,4 mer equipment phenolic labelling': 'Cluster#25',
#  '6.2-12 colo-2 all cells- factory connection torque verification': 'Cluster#9',
#  'csa punchlist - colo-2': 'Cluster#13',
#  'mep punchlist - colo-2': 'Cluster#13',
#  'ae/owner punchlist - colo-2': 'Cluster#13',
#  'colo-2 cell-1 ups pnl01 compass issues preventing cyt': 'Cluster#43',
#  'colo-2 cell-2 ups pnl01 compass issues preventing cyt': 'Cluster#45',
#  'colo-2 cell-3 ups pnl01 compass issues preventing cyt': 'Cluster#44',
#  'colo-2 cell-4 ups pnl01 compass issues preventing cyt': 'Cluster#46',
#  'colo-2 cell-1 open issues preventing yellow tags mer equipment': 'Cluster#43',
#  'colo-2 cell-2 open issues preventing yellow tags mer equipment': 'Cluster#45',
#  'colo-2 cell-3 open issues preventing yellow tags mer equipment': 'Cluster#44',
#  'colo-2 cell-4 open issues preventing yellow tags mer equipment': 'Cluster#46',
#  'colo-2': 'Cluster#9',
#  'colo-3 cx': 'Cluster#10',
#  'colo-3 cell-1': 'Cluster#43',
#  'colo-3 cell-3': 'Cluster#44',
#  'colo-3 cell-2': 'Cluster#45',
#  'colo-3 cell-4': 'Cluster#46',
#  'colo-3 adp01 & adp02 equipment shift': 'Cluster#10',
#  'level 3 cx- colo-3': 'Cluster#10',
#  'pad ready for mer colo-3 cell-1': 'Cluster#43',
#  'pad ready for mer colo-3 cell-3': 'Cluster#44',
#  'pad ready for mer colo-3 cell-2': 'Cluster#45',
#  'pad ready for mer colo-3 cell-4': 'Cluster#46',
#  'duct bank - colo-3 upm to vault ums run': 'Cluster#29',
#  'duct bank - vault to colo-3 upm': 'Cluster#29',
#  'duct bank - colo-3 upm to upm': 'Cluster#29',
#  'pull cross overs- colo-3 cell-3 to cell-4': 'Cluster#46',
#  'pull upm to upm colo-3 - cell-1 to cell-3': 'Cluster#44',
#  'pull upm to upm colo-3 cell 2- cell - 4': 'Cluster#29',
#  'pull- urs to colo-3': 'Cluster#10',
#  'ahu - roj colo-3 cell- 1': 'Cluster#28',
#  'ahu - roj colo-3 cell- 3': 'Cluster#28',
#  'ahu - roj colo-3 cell- 2': 'Cluster#28',
#  'ahu - roj colo-3 cell- 4': 'Cluster#28',
#  'msft delivery -ahu - roj colo-3 cell- 1': 'Cluster#28',
#  'msft delivery -ahu - roj colo-3 cell- 3': 'Cluster#28',
#  'msft delivery -ahu - roj colo-3 cell- 2': 'Cluster#28',
#  'msft delivery -ahu - roj colo-3 cell- 4': 'Cluster#28',
#  'pdu roj colo-3 cell-1': 'Cluster#43',
#  'msft delivery -pdu roj colo-3 cell-1': 'Cluster#43',
#  'pdu roj colo-3 cell-3': 'Cluster#44',
#  'msft delivery -pdu roj colo-3 cell-3': 'Cluster#44',
#  'pdu roj colo-3 cell-2': 'Cluster#45',
#  'msft delivery -pdu roj colo-3 cell-2': 'Cluster#45',
#  'pdu roj colo-3 cell-4': 'Cluster#46',
#  'msft delivery -pdu roj colo-3 cell-4': 'Cluster#46',
#  'punch list colo-3': 'Cluster#10',
#  'set- colo-3 ums': 'Cluster#33',
#  'pad- colo-3 ums': 'Cluster#10',
#  'duct bank - ums03 to upm colo-3 cell-1': 'Cluster#43',
#  'pull- ums03- upm colo-3 cell-1': 'Cluster#43',
#  'ums - roj colo-3': 'Cluster#10',
#  "yellow tagging for colo-3 upm's": 'Cluster#29',
#  'upm yellow tagging -colo-3 cell-1': 'Cluster#43',
#  'upm yellow tagging -colo-3 cell-3': 'Cluster#44',
#  'upm yellow tagging -colo-3 cell-2': 'Cluster#45',
#  'upm yellow tagging colo-3 cell-4': 'Cluster#46',
#  'colo-3 cell-1 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-3 cell-3 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-3 cell-2 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-3 cell-4 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-3 cell-1 se install ups batteries in cabinet': 'Cluster#43',
#  'colo-3 cell-4 se install ups batteries in cabinet': 'Cluster#46',
#  'colo-3 cell-3 se install ups batteries in cabinet': 'Cluster#44',
#  'colo-3 cell-2 se install ups batteries in cabinet': 'Cluster#45',
#  'neta test validation inpections- veca-eps-rts colo-3 cell-1': 'Cluster#43',
#  'neta test validation inpections- veca-eps-rts colo-3 cell-3': 'Cluster#44',
#  'neta test validation inpections- veca-eps-rts colo-3 cell-2': 'Cluster#45',
#  'neta test validation inpections- veca-eps-rts colo-3 cell-4': 'Cluster#46',
#  '6.1.39.1- colo-3 cell-1  gen belly tank failed pressure test': 'Cluster#43',
#  '6.1.39.2- colo-3 cell-1 replace belly tank and set gen': 'Cluster#43',
#  'colo-3 cell-1 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#43',
#  'colo-3  cell-3 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#44',
#  'colo-3 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#45',
#  'colo-3 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#46',
#  'colo-3 cell-1 install missing raceway & bussing within generator': 'Cluster#43',
#  'colo-3 cell-2 install missing raceway & bussing within generator': 'Cluster#45',
#  'colo-3 cell-3 install missing raceway & bussing within generator': 'Cluster#44',
#  'colo-3 cell-4 install missing raceway & bussing within generator': 'Cluster#46',
#  'nopc-18 remove colo-3 cell-1 transformer': 'Cluster#43',
#  'nopc-18 remove colo-3 cell-2 transformer': 'Cluster#45',
#  'nopc-18 remove colo-3 cell-3 transformer': 'Cluster#44',
#  'nopc-18 remove colo-3 cell-4 transformer': 'Cluster#46',
#  '6.1.55-colo-3 - fc factoy re-wire (rfi-502)': 'Cluster#10',
#  '6.1.01.1 mer 10a hrg retrofit colo-3 cell-1': 'Cluster#43',
#  '6.1.01.4 mer 10a hrg retrofit colo-3 cell-4': 'Cluster#46',
#  '6.1.01.3 mer 10a hrg retrofit colo-3 cell-3': 'Cluster#44',
#  '6.1.01.2 mer 10a hrg retrofit colo-3 cell-2': 'Cluster#45',
#  'nopc-18 reinstall colo-3 cell-1 transformer': 'Cluster#43',
#  'nopc-18 reinstall colo-3 cell-2 transformer': 'Cluster#45',
#  'nopc-18 reinstall colo-3 cell-3 transformer': 'Cluster#44',
#  'nopc-18 reinstall colo-3 cell-4 transformer': 'Cluster#46',
#  'colo-3 cell-3 remove inaccessible tray in mer': 'Cluster#44',
#  'colo-3 cell-3 reinstall tray in mer': 'Cluster#44',
#  'colo-3 cell-1 mer-ups battery disconnect modifications rework': 'Cluster#43',
#  'colo-3 cell-2 mer-ups battery disconnect modifications rework': 'Cluster#45',
#  'colo-3 cell-3 mer-ups battery disconnect modifications rework': 'Cluster#44',
#  'colo-3 cell-4 mer-ups battery disconnect modifications rework': 'Cluster#46',
#  'colo-3 cell-4 remove inaccessible tray in mer': 'Cluster#46',
#  'colo-3 cell-4 reinstall tray in mer': 'Cluster#46',
#  'colo-3 cell-1 remove inaccessible tray in mer': 'Cluster#43',
#  'colo-3 cell-1 reinstall tray in mer': 'Cluster#43',
#  'colo-3 cell-2 remove inaccessible tray in mer': 'Cluster#45',
#  'colo-3 cell-2 reinstall tray in mer': 'Cluster#45',
#  'colo-3 cell-3 conduit rework': 'Cluster#44',
#  'csa punchlist - colo-3': 'Cluster#13',
#  'mep punchlist - colo-3': 'Cluster#13',
#  'ae/owner punchlist - colo-3': 'Cluster#13',
#  'colo-3': 'Cluster#10',
#  'colo-4 cx': 'Cluster#11',
#  'colo-4 cell-1': 'Cluster#43',
#  'colo-4 cell-3': 'Cluster#44',
#  'colo-4 cell-2': 'Cluster#45',
#  'colo-4 cell-4': 'Cluster#46',
#  'colo-4 adp01 & adp02 equipment shift': 'Cluster#11',
#  'level 3 cx - colo-4': 'Cluster#11',
#  'pad ready for mer colo-4 cell-1': 'Cluster#43',
#  'pad ready for mer colo-4 cell-3': 'Cluster#44',
#  'pad ready for mer colo-4 cell-2': 'Cluster#45',
#  'pad ready for mer colo-4 cell-4': 'Cluster#46',
#  'duct bank - colo-4 upm to ums': 'Cluster#29',
#  'duct bank - vault to colo-4 upm': 'Cluster#29',
#  'duct bank - colo-4 upm to upm': 'Cluster#29',
#  'pull cross overs- colo-4 cell-3 to cell-4': 'Cluster#46',
#  'pull upm to upm colo-4 - cell-1 to cell-3': 'Cluster#44',
#  'pull upm to upm colo-4 cell 2- cell - 4': 'Cluster#29',
#  'pull- urs to colo-4': 'Cluster#11',
#  'pull- ums to colo-4': 'Cluster#11',
#  'msft delivery -ahu - roj colo-4 cell- 1': 'Cluster#28',
#  'ahu - roj colo-4 cell- 3': 'Cluster#28',
#  'ahu - roj colo-4 cell- 2': 'Cluster#28',
#  'ahu - roj colo-4 cell- 4': 'Cluster#28',
#  'ahu - roj colo-4 cell- 1': 'Cluster#28',
#  'msft delivery -ahu - roj colo-4 cell- 3': 'Cluster#28',
#  'msft delivery -ahu - roj colo-4 cell- 2': 'Cluster#28',
#  'msft delivery -ahu - roj colo-4 cell- 4': 'Cluster#28',
#  'upm - roj - colo-4 cell- 1': 'Cluster#29',
#  'msft delivery -upm - roj - colo-4 cell- 1 (12/7/2020)': 'Cluster#29',
#  'upm - roj - colo-4 cell- 3': 'Cluster#29',
#  'msft delivery -upm - roj - colo-4 cell- 3 (12/18/2020)': 'Cluster#29',
#  'msft delivery -upm - roj - colo-4 cell- 2 (12/7/2020)': 'Cluster#29',
#  'upm - roj - colo-4 cell- 2': 'Cluster#29',
#  'upm - roj - colo-4 cell- 4': 'Cluster#29',
#  'msft delivery -upm - roj - colo-4 cell- 4 (12/18/2020)': 'Cluster#29',
#  'pdu roj colo-4 cell-1': 'Cluster#43',
#  'msft delivery -pdu roj colo-4 cell-1': 'Cluster#43',
#  'pdu roj colo-4 cell-3': 'Cluster#44',
#  'msft delivery -pdu roj colo-4 cell-3': 'Cluster#44',
#  'pdu roj colo-4 cell-2': 'Cluster#45',
#  'msft delivery -pdu roj colo-4 cell-2': 'Cluster#45',
#  'pdu roj colo-4 cell-4': 'Cluster#46',
#  'msft delivery -pdu roj colo-4 cell-4': 'Cluster#46',
#  'punch list colo-4': 'Cluster#11',
#  'set- colo-4 ums': 'Cluster#33',
#  'pad- colo-4 ums': 'Cluster#11',
#  'duct bank - ums04 to upm colo-4 cell-1': 'Cluster#43',
#  'pull- ums04- upm colo-4 cell-1': 'Cluster#43',
#  'ums - roj colo-4': 'Cluster#11',
#  "yellow tagging for colo-4 upm's": 'Cluster#29',
#  'upm yellow tagging -colo-4 cell-1': 'Cluster#43',
#  'upm yellow tagging -colo-4 cell-3': 'Cluster#44',
#  'upm yellow tagging -colo-4 cell-2': 'Cluster#45',
#  'upm yellow tagging -colo-4 cell-4': 'Cluster#46',
#  'colo-4 cell-1 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-4 cell-3 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-4 cell-2 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-4 cell-4 install tube steel & cable tray transition per rfi#432': 'Cluster#54',
#  'colo-4 cell-1 se install ups batteries in cabinet': 'Cluster#43',
#  'colo-4 cell-4 se install ups batteries in cabinet': 'Cluster#46',
#  'colo-4 cell-3 se install ups batteries in cabinet': 'Cluster#44',
#  'colo-4 cell-2 se install ups batteries in cabinet': 'Cluster#45',
#  'neta test validation inpections- veca-eps-rts colo-4 cell-1': 'Cluster#43',
#  'neta test validation inpections- veca-eps-rts colo-4 cell-3': 'Cluster#44',
#  'neta test validation inpections- veca-eps-rts colo-4 cell-2': 'Cluster#45',
#  'neta test validation inpections- veca-eps-rts colo-4 cell-4': 'Cluster#46',
#  'colo-4 cell-1 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#43',
#  'colo-4 cell-3 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#44',
#  'colo-4 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#45',
#  'colo-4 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#46',
#  'colo-4 cell-1 install missing raceway & bussing within generator': 'Cluster#43',
#  'colo-4 cell-2 install missing raceway & bussing within generator': 'Cluster#45',
#  'colo-4 cell-3 install missing raceway & bussing within generator': 'Cluster#44',
#  'colo-4 cell-4 install missing raceway & bussing within generator': 'Cluster#46',
#  '6.2.03- replace damaged upm in colo-4 cell-4': 'Cluster#46',
#  'nopc-18 remove colo-4 cell-1 transformer': 'Cluster#43',
#  'nopc-18 remove colo-4 cell-2 transformer': 'Cluster#45',
#  'nopc-18 remove colo-4 cell-3 transformer': 'Cluster#44',
#  'nopc-18 remove colo-4 cell-4 transformer': 'Cluster#46',
#  '6.1.55-colo-4 - fc factoy re-wire (rfi-502)': 'Cluster#11',
#  '6.1.01.1 mer 10a hrg retrofit colo-4 cell-1': 'Cluster#43',
#  '6.1.01.4 mer 10a hrg retrofit colo-4 cell-4': 'Cluster#46',
#  '6.1.01.3 mer 10a hrg retrofit colo-4 cell-3': 'Cluster#44',
#  '6.1.01.2 mer 10a hrg retrofit colo-4 cell-2': 'Cluster#45',
#  'nopc-18 reinstall colo-4 cell-1 transformer': 'Cluster#43',
#  'nopc-18 reinstall colo-4 cell-2 transformer': 'Cluster#45',
#  'nopc-18 reinstall colo-4 cell-3 transformer': 'Cluster#44',
#  'nopc-18 reinstall colo-4 cell-4 transformer': 'Cluster#46',
#  'colo-4 cell-1 mer-ups battery disconnect modifications rework': 'Cluster#43',
#  'colo-4 cell-2 mer-ups battery disconnect modifications rework': 'Cluster#45',
#  'colo-4 cell-3 mer-ups battery disconnect modifications rework': 'Cluster#44',
#  'colo-4 cell-4 mer-ups battery disconnect modifications rework': 'Cluster#46',
#  'colo-4 cell-1 remove inaccessible tray in mer': 'Cluster#43',
#  'colo-4 cell-1 reinstall tray in mer': 'Cluster#43',
#  'colo-4 cell-2 remove inaccessible tray in mer': 'Cluster#45',
#  'colo-4 cell-2 reinstall tray in mer': 'Cluster#45',
#  'colo-4 cell-3 remove inaccessible tray in mer': 'Cluster#44',
#  'colo-4 cell-3 reinstall tray in mer': 'Cluster#44',
#  'colo-4 cell-4 remove inaccessible tray in mer4': 'Cluster#46',
#  'colo-4 cell-4 reinstall tray in mer': 'Cluster#46',
#  '#4. extreme heat - 6/28/21- 7/2/21(effecting colo-4 yard work)': 'Cluster#11',
#  'colo-4 cell-1 conduit rework': 'Cluster#43',
#  'colo-4 cell-2 conduit rework': 'Cluster#45',
#  'colo-4 cell-3 conduit rework': 'Cluster#44',
#  'colo-4 cell-4 conduit rework': 'Cluster#46',
#  'csa punchlist - colo-4': 'Cluster#13',
#  'mep punchlist - colo-4': 'Cluster#13',
#  'ae/owner punchlist - colo-4': 'Cluster#13',
#  'colo-4': 'Cluster#11',
#  'update#4': 'Cluster#12',
#  'a/e & owner-rep punchlist walk': 'Cluster#13',
#  'complete a/e punchlist': 'Cluster#13',
#  'csa punchlist - colo-1': 'Cluster#20',
#  'mep punchlist - colo-1': 'Cluster#20',
#  'ae/owner punchlist - colo-1': 'Cluster#20',
#  'punchlist': 'Cluster#13',
#  'update#6': 'Cluster#14',
#  'update#7': 'Cluster#15',
#  'update#8': 'Cluster#16',
#  'update#10': 'Cluster#17',
#  'update#12': 'Cluster#18',
#  'admin/ colo-1': 'Cluster#20',
#  'admin/ colo 1': 'Cluster#19',
#  'admin/colo 1': 'Cluster#19',
#  'exterior equipment admin': 'Cluster#19',
#  'admin/colo-1 network startup': 'Cluster#21',
#  'level 3 cx - admin and colo1': 'Cluster#19',
#  'admin -electrical underground rough-in': 'Cluster#39',
#  'foundation start - admin/colo 1': 'Cluster#19',
#  'steel erection - admin/colo 1': 'Cluster#19',
#  'fit out start - admin/colo 1': 'Cluster#19',
#  'sog- admin/ colo1 start': 'Cluster#19',
#  'insulated metal panel start- admin/colo 1': 'Cluster#19',
#  'roof panel start -admin/colo 1': 'Cluster#35',
#  'lead time for admin/colo 1 yard steel': 'Cluster#19',
#  'admin / colo 1 csa complete': 'Cluster#19',
#  'punch list - admin/colo 1': 'Cluster#19',
#  'admin/colo-1 bim signoff': 'Cluster#21',
#  'duct back- admin upm to vault': 'Cluster#29',
#  'duct bank admin upm to colo-1 upm': 'Cluster#29',
#  'pull upm to upm admin to colo-1 cell -2': 'Cluster#29',
#  'pull- urs to admin': 'Cluster#19',
#  'ist admin/colo 1': 'Cluster#19',
#  'msft delivery - admin gen submittal release': 'Cluster#33',
#  'msft delivery -admin- gen- roj': 'Cluster#19',
#  'msft delivery - admin - upm - roj': 'Cluster#29',
#  'admin gen- roj': 'Cluster#19',
#  'admin overhead rough-in (drb#2)': 'Cluster#19',
#  'admin electrical room build out (drb#2)': 'Cluster#39',
#  'admin lighting installation (drb#2)': 'Cluster#19',
#  'term admin - upm': 'Cluster#29',
#  'tco admin/colo 1': 'Cluster#19',
#  'substantial completion admin/colo 1': 'Cluster#19',
#  'lock down admin/colo 1': 'Cluster#19',
#  'linx mobilization to admin/colo-1': 'Cluster#52',
#  'admin gen scr testing and burnins': 'Cluster#19',
#  'upm yellow tagging - admin & colo-1 cell-1': 'Cluster#43',
#  'lead time for missing admin gen bussing': 'Cluster#19',
#  'admin gen bussing install': 'Cluster#19',
#  'admin - neta test validation inpections- veca-eps-rts admin': 'Cluster#19',
#  '6.1.41 - incorrect lugs for admin gen main bussing': 'Cluster#19',
#  '6.1.54- tcm awaiting admin siemens break tank parts': 'Cluster#19',
#  'print new dc arc flash labels for admin elp': 'Cluster#19',
#  'admin-ups battery disconnect modifications rework': 'Cluster#19',
#  'rfi-552 admin msb to ups battery disconnect solution approval': 'Cluster#19',
#  '6.1-98 admin/colo-1 asco epms connectivity issues': 'Cluster#21',
#  "6.1-88  admin/ colo-1 mer/admin ups l3 testing (includes shutdown to move pqm's & pqm data post proccessing)": 'Cluster#25',
#  'admin': 'Cluster#19',
#  'colo-1 cx': 'Cluster#20',
#  'colo-1 fit out': 'Cluster#20',
#  'colo-1 cell-1': 'Cluster#43',
#  'colo-1 cell-2': 'Cluster#45',
#  'colo-1 cell-3': 'Cluster#44',
#  'colo-1 cell-4': 'Cluster#46',
#  'colo-1 adp01 & adp02 equipment shift': 'Cluster#20',
#  'pad ready for mer colo-1 cell-1': 'Cluster#43',
#  'pad ready for mer colo-1 cell-3': 'Cluster#44',
#  'pad ready for mer colo-1 cell-2': 'Cluster#45',
#  'pad ready for mer colo-1 cell-4': 'Cluster#46',
#  'duct bank- colo-1 upm to north vault': 'Cluster#29',
#  'pull cross overs- colo-1 cell-3 to cell-4': 'Cluster#46',
#  'pull upm to upm colo-1 - cell-1 to cell-3': 'Cluster#44',
#  'pull upm to upm colo-1 cell 2- cell - 4': 'Cluster#29',
#  'pull- ums to colo-1,2,3': 'Cluster#20',
#  'ahu - roj colo-1 cell- 1': 'Cluster#28',
#  'ahu - roj colo-1 cell- 3': 'Cluster#28',
#  'ahu - roj colo-1 cell- 2': 'Cluster#28',
#  'ahu - roj colo-1 cell- 4': 'Cluster#28',
#  'msft delivery -ahu - roj colo-1 cell- 1(11/2/20)': 'Cluster#28',
#  'msft delivery -ahu - roj colo-1 cell- 3': 'Cluster#28',
#  'msft delivery -ahu - roj colo-1 cell- 2 (11/2/20)': 'Cluster#28',
#  'msft delivery -ahu - roj colo-1 cell- 4': 'Cluster#28',
#  'upm roj colo-1 cell-1': 'Cluster#43',
#  'msft delivery -upm roj colo-1 cell-1 (psr roj -9/19/2020)': 'Cluster#43',
#  'upm roj colo-1 cell-3': 'Cluster#44',
#  'msft delivery -upm roj colo-1 cell-3 (psr roj -9/28/2020)': 'Cluster#44',
#  'msft delivery -upm roj colo-1 cell-2 (psr roj -10/13/2020)': 'Cluster#45',
#  'upm roj colo-1 cell-2': 'Cluster#45',
#  'upm roj colo-1 cell-4': 'Cluster#46',
#  'msft delivery -upm roj colo-1 cell-4 (psr roj -10/28/2020)': 'Cluster#46',
#  'pdu roj colo-1 cell-1': 'Cluster#43',
#  'msft delivery -pdu roj colo-1 cell-1': 'Cluster#43',
#  'pdu roj colo-1 cell-3': 'Cluster#44',
#  'msft delivery -pdu roj colo-1 cell-3': 'Cluster#44',
#  'pdu roj colo-1 cell-2': 'Cluster#45',
#  'msft delivery -pdu roj colo-1 cell-2': 'Cluster#45',
#  'pdu roj colo-1 cell-4': 'Cluster#46',
#  'msft delivery -pdu roj colo-1 cell-4': 'Cluster#46',
#  'msft delivery - colo-1 gen submittal release': 'Cluster#33',
#  'msft delivery - mer submittal colo-1': 'Cluster#25',
#  'water treatment delivery colo-1': 'Cluster#20',
#  'set- colo-1 ums': 'Cluster#33',
#  'pad- colo-1 ums': 'Cluster#20',
#  'duct bank - ums01 to upm colo-1 cell-1': 'Cluster#43',
#  'pull- ums01- upm colo-1 cell-1': 'Cluster#43',
#  'colo-1 cell-1 rearrange roxtec blocks per coordination layout': 'Cluster#43',
#  'colo-1 cell-1 interior mer conduit installation building side complete march1st (mer discovery corrections & signoff)': 'Cluster#49',
#  'colo-1 cell-1 mer flex conduit fixes': 'Cluster#43',
#  'colo-1 cell-1 remove/ replace busway & hangers': 'Cluster#43',
#  'colo-1 cell-3 remove/ replace busway & hangers': 'Cluster#44',
#  'colo-1 cell-2 remove/ replace busway & hangers': 'Cluster#45',
#  'colo-1 cell-4 remove/ replace busway & hangers': 'Cluster#46',
#  'colo-1 cell-3 mer flex conduit fixes': 'Cluster#44',
#  'colo-1 cell-2 mer flex conduit fixes': 'Cluster#45',
#  'colo-1 cell-4 mer flex conduit fixes': 'Cluster#46',
#  'colo-1 cell3 rearrange roxtec blocks per coordination layout': 'Cluster#24',
#  'colo-1 cell3 interior mer conduit installation building side': 'Cluster#49',
#  'colo-1 cell2 rearrange roxtec blocks per coordination layout': 'Cluster#23',
#  'colo-1 cell2 interior mer conduit installation building side': 'Cluster#49',
#  'colo-1 cell4 rearrange roxtec blocks per coordination layout': 'Cluster#20',
#  'colo-1 cell4 interior mer conduit installation building side': 'Cluster#49',
#  'upm yellow tagging - colo-1 cell-3': 'Cluster#44',
#  'upm yellow tagging - colo-1 cell-2': 'Cluster#45',
#  'upm yellow tagging - colo-1 cell-4': 'Cluster#46',
#  'colo-1 cell-1 se install ups batteries in cabinet': 'Cluster#43',
#  'colo-1 cell-4 se install ups batteries in cabinet': 'Cluster#46',
#  'colo-1 cell-3 se install ups batteries in cabinet': 'Cluster#44',
#  'colo-1 cell-2 se install ups batteries in cabinet': 'Cluster#45',
#  '6.1.34.1 colo-1 cell-1 rework on ats input conductors': 'Cluster#43',
#  'neta test validation inpections- veca-eps-rts colo-1 cell-1': 'Cluster#43',
#  '6.1.34.2 colo-1 cell-2 rework on ats input conductors': 'Cluster#45',
#  '6.1.34.3 colo-1 cell-3 rework on ats input conductors': 'Cluster#44',
#  '6.1.34.4 colo-1 cell-4 rework on ats input conductors': 'Cluster#46',
#  'colo-1 cell-1 field modification of tray': 'Cluster#43',
#  'colo-1 cell-2 field modification of tray': 'Cluster#45',
#  '6.1.01.1 mer 10a hrg retrofit colo-1 cell-1': 'Cluster#43',
#  '6.1.01.4 mer 10a hrg retrofit colo-1 cell-4': 'Cluster#46',
#  '6.1.01.3 mer 10a hrg retrofit colo-1 cell-3': 'Cluster#44',
#  '6.1.01.2 mer 10a hrg retrofit colo-1 cell-2': 'Cluster#45',
#  'neta test validation inpections- veca-eps-rts colo-1 cell-3': 'Cluster#44',
#  'neta test validation inpections- veca-eps-rts colo-1 cell-2': 'Cluster#45',
#  'neta test validation inpections- veca-eps-rts colo-1 cell-4': 'Cluster#46',
#  '6.1.47- colo-1 cell-2 ups01- factory test thermal event': 'Cluster#45',
#  'colo-1 cell-1 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#43',
#  'colo-1 cell-3 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#44',
#  'colo-1 cell-2 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#45',
#  'colo-1 cell-4 late start to pulling pdu feeders due to space constraint in mer (adp in front of msb)': 'Cluster#46',
#  'nopc-18 remove colo-1 cell-1 transformer': 'Cluster#43',
#  'nopc-18 remove colo-1 cell-2 transformer': 'Cluster#45',
#  'nopc-18 remove colo-1 cell-3 transformer': 'Cluster#44',
#  'nopc-18 remove colo-1 cell-4 transformer': 'Cluster#46',
#  '6.1.51-colo-1 cell-1,2 factory conductors not terminated per drawings': 'Cluster#43',
#  '6.1.55-colo-1 - fc factoy re-wire (rfi-502)': 'Cluster#20',
#  '6.1.49 - colo-1 cell-1 awaiting ground lug solution, procurement, installation of labelling ats 01-06': 'Cluster#43',
#  '6.1.53-colo-1 cell-1,2 ups01, pnl01 awaiting missing breakers': 'Cluster#43',
#  '6.1.53-colo-1 cell-1,2,3,4 ups01, pnl01 install/ term missing breakers': 'Cluster#43',
#  '6.1.59 (6.1.51 carryover) -colo-1 cell-1,2 factory conductors exertherm corrections': 'Cluster#43',
#  'nopc-18 reinstall colo-1 cell-1 transformer': 'Cluster#43',
#  'nopc-18 reinstall colo-1 cell-2 transformer': 'Cluster#45',
#  'nopc-18 reinstall colo-1 cell-3 transformer': 'Cluster#44',
#  'nopc-18 reinstall colo-1 cell-4 transformer': 'Cluster#46',
#  '6.1.58-rfi-528- colo-1 - sf/rf circuitry & terminal block rework': 'Cluster#27',
#  '6.1.56 - colo-1 awaiting msb/adp ground lug replacements, installation of labelling': 'Cluster#20',
#  'colo-1 cell-1 mer-ups battery disconnect modifications rework': 'Cluster#43',
#  'colo-1 cell-2 mer-ups battery disconnect modifications rework': 'Cluster#45',
#  'colo-1 cell-3 mer-ups battery disconnect modifications rework': 'Cluster#44',
#  'colo-1 cell-4 mer-ups battery disconnect modifications rework': 'Cluster#46',
#  '6.1-88 colo-1 mer awaiting updated ups l3 test script approval': 'Cluster#25',
#  '6.1-89 rfi574- colo-1 relocating msb epms device to different cabinet': 'Cluster#20',
#  '6.1-106 colo-1 cell-2 ups01 power module failure': 'Cluster#45',
#  'colo-1': 'Cluster#20',
#  'admin/colo-1': 'Cluster#21',
#  'term- jaz  to structure- (incl stress cones) from ums': 'Cluster#47',
#  'start superstructure': 'Cluster#22',
#  'structure': 'Cluster#22',
#  'l2 - cx': 'Cluster#23',
#  'l2 cx complete (yellow tag)': 'Cluster#23',
#  'start of l2 cx': 'Cluster#23',
#  'colo1 cell2 mer security/telecom missing raceway installation': 'Cluster#33',
#  'colo1 cell2 interior mer conduit installation utility side': 'Cluster#25',
#  'se- completed l2 qc checklist': 'Cluster#33',
#  '6.1.26.1 l2/l3 scripts se mer overall script': 'Cluster#33',
#  '6.1.26.2 l2/l3 scripts siemens bas sat scripts': 'Cluster#24',
#  'colo2 cell2 interior mer conduit installation utility side(delete)': 'Cluster#25',
#  'colo2 cell2 mer security/telecom missing raceway installation': 'Cluster#33',
#  'l2': 'Cluster#23',
#  'l3 - cx': 'Cluster#24',
#  'l3 cx start': 'Cluster#24',
#  'l3 cx complete (green tag)': 'Cluster#24',
#  'colo1 cell3 mer security/telecom missing raceway installation': 'Cluster#33',
#  'colo1 cell3 interior mer conduit installation utility side': 'Cluster#25',
#  'colo2 cell3 interior mer conduit installation utility side': 'Cluster#25',
#  'colo2 cell3 mer security/telecom missing raceway installation': 'Cluster#33',
#  '6.1.63- colo1-ups01-pnl01 compass issues constraining l3o?=s': 'Cluster#24',
#  'l3': 'Cluster#24',
#  'pull / term / test conductors ( mer to pdu)': 'Cluster#31',
#  'assemble mer & complete shipping split (se)': 'Cluster#33',
#  'msft delivery -mer roj colo 1 cell 1 (11/6/20)': 'Cluster#25',
#  'ready to set exterior mer': 'Cluster#33',
#  'ready to set mer': 'Cluster#33',
#  'msft delivery -mer roj colo 1 cell 3 (11/20/20)': 'Cluster#25',
#  'msft delivery -mer roj colo 1 cell 2 (11/13/20)': 'Cluster#25',
#  'msft delivery -mer roj colo 1 cell 4 (11/30/20)': 'Cluster#25',
#  'msft delivery -mer roj colo 2 cell 1 (12/15/20)': 'Cluster#25',
#  'msft delivery -mer roj colo 2 cell 2 (12/22/20)': 'Cluster#25',
#  'msft delivery -mer roj colo 2 cell 3 (12/28/20)': 'Cluster#25',
#  'msft delivery -mer roj colo 2 cell 4 (1/5/20)': 'Cluster#25',
#  'msft delivery -mer roj colo 3 cell 1 (1/29/21)': 'Cluster#25',
#  'msft delivery -mer roj colo 3 cell 3 (2/12/21)': 'Cluster#25',
#  'msft delivery -mer roj colo 3 cell 2 (2/5/21)': 'Cluster#25',
#  'msft delivery -mer roj colo 3 cell 4 (2/19/21)': 'Cluster#25',
#  'msft delivery -mer roj colo 4 cell 1 (3/12/21)': 'Cluster#25',
#  'msft delivery -mer roj colo 4 cell 3 (3/26/21)': 'Cluster#25',
#  'msft delivery -mer roj colo 4 cell 2 (3/19/21)': 'Cluster#25',
#  'msft delivery -mer roj colo 4 cell 4 (4/2/21)': 'Cluster#25',
#  'lift & set mer in place': 'Cluster#33',
#  'gen & upm to mer cable bus install': 'Cluster#29',
#  'gen & upm to mer cable bus instal': 'Cluster#29',
#  'install roxtec blocks and install tray/conduit from roxtec to mer (drb#3)': 'Cluster#25',
#  'install added overhead rough in mer mech eq (drb#3)': 'Cluster#25',
#  'sure steel - pemb mer penetration framing': 'Cluster#25',
#  'remaining mer raceway across mech chase': 'Cluster#33',
#  'remaining post mer raceway across mech chase': 'Cluster#33',
#  'colo1 cell1 mer security/telecom missing raceway installation': 'Cluster#33',
#  'colo1 cell1 interior mer conduit installation utility side': 'Cluster#25',
#  'colo1 cell4 mer security/telecom missing raceway installation': 'Cluster#33',
#  'colo1 cell4 interior mer conduit installation utility side': 'Cluster#25',
#  'install mer supply duct': 'Cluster#25',
#  'ats equipment yellow tagging (s2 from mer)': 'Cluster#25',
#  "6.1.01.0 awaiting mer 10a hrg's (lead time= 8 weeks from 2/2/2021)": 'Cluster#25',
#  'colo2 cell1 interior mer conduit installation utility side': 'Cluster#25',
#  'colo2 cell4 interior mer conduit installation utility side': 'Cluster#25',
#  'colo2 cell4 interior mer conduit installation building side': 'Cluster#49',
#  'colo2 cell1 mer security/telecom missing raceway installation': 'Cluster#33',
#  'colo2 cell4 mer security/telecom missing raceway installation': 'Cluster#33',
#  'mer shipping split connection safety standown & rca review': 'Cluster#25',
#  '6.1.44- mer battery monitoring software o?= constraint to epms checkouts/point o?= point(needed by 4/23)': 'Cluster#25',
#  'rubicon msb inspection complete (ready for transformer reinstall)': 'Cluster#25',
#  'msb inspection complete (ready for transformer reinstall)': 'Cluster#25',
#  'mer': 'Cluster#25',
#  'mv ductbanks procurement drb#1 jaz to ums/urs & upm to ums': 'Cluster#47',
#  'mv wire procurement drb#1 jaz to ums/urs & upm to ums': 'Cluster#47',
#  'ums vault procurement drb#1': 'Cluster#32',
#  'drb#1 bim modeling & coordination drb#1 jaz to ums/urs & upm to ums': 'Cluster#47',
#  'upm to ums vaults procurement drb#1': 'Cluster#42',
#  'drb#1': 'Cluster#26',
#  'terms- ums': 'Cluster#27',
#  'terms- urs': 'Cluster#27',
#  'electrical feeders to mechanical equipment pull-test-term': 'Cluster#41',
#  'pull/term/test pdu to power bus': 'Cluster#31',
#  'epms pull wire / term / test': 'Cluster#27',
#  'bms pull wire / term / test': 'Cluster#27',
#  'electrical equipment yellow tagging (field terminated equipment)': 'Cluster#39',
#  'generator & utility power test-term': 'Cluster#30',
#  'term colo -1 cell-1 upm': 'Cluster#43',
#  'term colo -1 cell-2 upm': 'Cluster#45',
#  'term colo -2 cell-1 upm': 'Cluster#43',
#  'term colo -2 cell-2 upm': 'Cluster#45',
#  'term colo -3 cell-1 upm': 'Cluster#43',
#  'term colo -3 cell-2 upm': 'Cluster#45',
#  'term colo -4 cell-1 upm': 'Cluster#43',
#  'term colo -4 cell-2 upm': 'Cluster#45',
#  'term- urs- load side': 'Cluster#27',
#  'term urs- line side': 'Cluster#27',
#  'term- ums- load side': 'Cluster#27',
#  'term- ums- line side': 'Cluster#27',
#  'term- jas to urs- (incl stress cones)': 'Cluster#27',
#  'fluid cooler wire install and term': 'Cluster#27',
#  'term colo -1 cell-4 upm': 'Cluster#46',
#  'term colo -2  cell-4 upm': 'Cluster#46',
#  'term colo -3  cell-4 upm': 'Cluster#46',
#  'term colo -4  cell-4 upm': 'Cluster#46',
#  'term colo -1 cell-3 upm': 'Cluster#44',
#  'term colo -2 cell-3 upm': 'Cluster#44',
#  'term colo -3 cell-3 upm': 'Cluster#44',
#  'term colo -4 cell-3 upm': 'Cluster#44',
#  'install additional electrical feeders for  mech equipment additional term (drb#3)': 'Cluster#39',
#  'term- ums01- load side': 'Cluster#27',
#  'term- ums02- load side': 'Cluster#27',
#  'term- ums03- load side': 'Cluster#27',
#  'term- ums04- load side': 'Cluster#27',
#  'term colo -2 cell-4 upm': 'Cluster#46',
#  'term colo -3 cell-4 upm': 'Cluster#46',
#  'term colo -4 cell-4 upm': 'Cluster#46',
#  'generator term': 'Cluster#30',
#  'determined startline hanger design issue & approve replacement hangers': 'Cluster#27',
#  'generator & utility power term': 'Cluster#30',
#  'pdu termination crew downtime due to covid-19': 'Cluster#31',
#  '6.1.11  liftstation #3 bas install / pull wire / term backplanes': 'Cluster#27',
#  'remaining mechanical equipment (adp01) termimations': 'Cluster#41',
#  'complete beneficial use - intermediate distribution frame (idf) ': 'Cluster#33',
#  'term': 'Cluster#27',
#  'electrical surface mounted rough-in above ahu': 'Cluster#39',
#  'ahu/doas equipment setting': 'Cluster#33',
#  'ahu': 'Cluster#28',
#  'urs to upm': 'Cluster#29',
#  'ums to upm': 'Cluster#29',
#  'west upms': 'Cluster#50',
#  'east upms': 'Cluster#51',
#  "exterior equipment pads - for upm's": 'Cluster#29',
#  'set electrical equipment-upm': 'Cluster#39',
#  'set electrical equipment-upm cell -3': 'Cluster#39',
#  'duct bank  - colo1- upm to upm': 'Cluster#29',
#  'vault- set north vault- along upm to vault': 'Cluster#33',
#  'vault - set south vault along upm to vault': 'Cluster#33',
#  'duct bank  - colo2- upm to upm': 'Cluster#29',
#  'upm - roj - colo2- cell-1': 'Cluster#43',
#  'msft delivery -upm - roj - colo2- cell-1 (11/25/2020)': 'Cluster#43',
#  'upm - roj - colo2- cell-3': 'Cluster#44',
#  'msft delivery -upm - roj - colo2- cell-3 (11/25/2020)': 'Cluster#44',
#  'msft delivery -upm - roj - colo2- cell-2 (11/25/2020)': 'Cluster#45',
#  'upm - roj - colo2- cell-2': 'Cluster#45',
#  'upm - roj - colo2- cell-4': 'Cluster#46',
#  'msft delivery -upm - roj - colo2- cell-4 (11/25/2020)': 'Cluster#46',
#  'upm - roj - colo3- cell-1': 'Cluster#43',
#  'msft delivery -upm - roj - colo3- cell-1 (11/23/2020)': 'Cluster#43',
#  'upm - roj - colo3- cell-3': 'Cluster#44',
#  'msftdelivery -upm - roj - colo3- cell-3 (11/23/2020)': 'Cluster#44',
#  'upm - roj - colo3- cell-2': 'Cluster#45',
#  'msft delivery -upm - roj - colo3- cell-2 (11/23/2020)': 'Cluster#45',
#  'upm - roj - colo3- cell-4': 'Cluster#46',
#  'msft delivery -upm - roj - colo3- cell-4 (11/23/2020)': 'Cluster#46',
#  'msft delivery - upm submittal release': 'Cluster#33',
#  'upm - roj': 'Cluster#29',
#  'submit and approve shop drawings for upm junstion box': 'Cluster#29',
#  'upm': 'Cluster#29',
#  'generator & utility power pull': 'Cluster#30',
#  'generator & utility power pull-test': 'Cluster#30',
#  'generator roj colo 1- cell-1': 'Cluster#43',
#  'msft delivery -generator roj colo 1- cell-1': 'Cluster#43',
#  'generator roj colo 1- cell-3': 'Cluster#44',
#  'msft delivery -generator roj colo 1- cell-3': 'Cluster#44',
#  'generator roj colo 1- cell-2': 'Cluster#45',
#  'msft delivery -generator roj colo 1- cell-2': 'Cluster#45',
#  'generator roj colo 1- cell-4': 'Cluster#46',
#  'msft delivery -generator roj colo 1- cell-4': 'Cluster#46',
#  'msft delivery -generator roj colo 2- cell - 1': 'Cluster#30',
#  'generator roj colo 2- cell - 1': 'Cluster#30',
#  'generator roj colo 2- cell - 3': 'Cluster#30',
#  'msft delivery -generator roj colo 2- cell - 3': 'Cluster#30',
#  'generator roj colo 2- cell - 2': 'Cluster#30',
#  'msft delivery -generator roj colo 2- cell - 2': 'Cluster#30',
#  'generator roj colo 2- cell - 4': 'Cluster#30',
#  'msft delivery -generator roj colo 2- cell - 4': 'Cluster#30',
#  'generator roj colo 3- cell - 1': 'Cluster#30',
#  'msft delivery -generator roj colo 3- cell - 1': 'Cluster#30',
#  'generator roj colo 3- cell - 3': 'Cluster#30',
#  'msft delivery -generator roj colo 3- cell - 3': 'Cluster#30',
#  'generator roj colo 3- cell - 2': 'Cluster#30',
#  'msft delivery -generator roj colo 3- cell - 2': 'Cluster#30',
#  'generator roj colo 3- cell - 4': 'Cluster#30',
#  'msft delivery -generator roj colo 3- cell - 4': 'Cluster#30',
#  'generator roj colo 4- cell - 3': 'Cluster#30',
#  'msft delivery -generator roj colo 4- cell - 3': 'Cluster#30',
#  'generator roj colo 4- cell - 2': 'Cluster#30',
#  'msft delivery -generator roj colo 4- cell - 2': 'Cluster#30',
#  'generator roj colo 4- cell - 4': 'Cluster#30',
#  'msft delivery -generator roj colo 4- cell - 4': 'Cluster#30',
#  'generator roj colo 4- cell - 1': 'Cluster#30',
#  'msft delivery -generator roj colo 4- cell - 1': 'Cluster#30',
#  'generators ready for fuel': 'Cluster#30',
#  'generator': 'Cluster#30',
#  "pdu's installation": 'Cluster#31',
#  'msft delivery - pdu submittal release': 'Cluster#33',
#  '6.1.38 pdu mcb01 loto provisions': 'Cluster#31',
#  'pdu': 'Cluster#31',
#  'electrical procurement': 'Cluster#39',
#  'core & shell procurement': 'Cluster#32',
#  'mechanical procurement': 'Cluster#41',
#  'electrical ofci procurement': 'Cluster#39',
#  'mv ductbanks procurement': 'Cluster#32',
#  'telecom ductbank / vaults procurement': 'Cluster#42',
#  'mv wire procurement': 'Cluster#32',
#  'underground grounding procurement': 'Cluster#32',
#  'electrical long lead equipment procurement (cablebus, panel boards)': 'Cluster#39',
#  'urs vault procurement': 'Cluster#32',
#  'water treatment skids procurement ( sourcing materials and materail approval only)': 'Cluster#32',
#  'wire mesh procurement': 'Cluster#32',
#  'procurement': 'Cluster#32',
#  'contractor setup': 'Cluster#33',
#  'funding release packages': 'Cluster#33',
#  'phase 1': 'Cluster#33',
#  'aggregate road base': 'Cluster#33',
#  'aggregate base course': 'Cluster#33',
#  'set electrical equipment incl. oh raceways': 'Cluster#39',
#  'concrete floor sealing/epoxy': 'Cluster#33',
#  'security devices & trim': 'Cluster#33',
#  'set exterior electrical ofci equipment - gen': 'Cluster#39',
#  'set exterior mechanical ofci equipment (fc)': 'Cluster#41',
#  'fire riser installation': 'Cluster#33',
#  'phase 1a - funding release': 'Cluster#33',
#  'set exterior mechanical ofci equipment (fc / wte / pumps)': 'Cluster#41',
#  'set exterior electrical ofci equipment': 'Cluster#39',
#  'set exterior mechanical cfci equipment (remaning mini splits)': 'Cluster#41',
#  'ready to set exterior mechanical equipment': 'Cluster#41',
#  'pemb release': 'Cluster#33',
#  'phase 1b - funding release': 'Cluster#33',
#  'phase 1c - funding release': 'Cluster#33',
#  'hydronic pipe flush (open and closed loop)': 'Cluster#33',
#  'set mechanical  equipment': 'Cluster#41',
#  'phase 1c1- msft commitment for steel crew': 'Cluster#33',
#  'set mv gear (ums)': 'Cluster#33',
#  'secondary steel': 'Cluster#33',
#  'set mv gear (urs)': 'Cluster#33',
#  'set ums vault': 'Cluster#33',
#  'vault- set 1st vault along ums duct bank run': 'Cluster#33',
#  'set urs vault': 'Cluster#33',
#  'duct bank- building to urs(upto horse shoe) - 2nd half': 'Cluster#49',
#  'duct bank - vault to vault along ums duct run - horseshoe': 'Cluster#33',
#  'vault- set vault along  urs to jaz run': 'Cluster#47',
#  'vault- set vault along ums to jaz run': 'Cluster#47',
#  'vault - set north vault along vault to urs run': 'Cluster#33',
#  'vault - set south vault along vault to urs run': 'Cluster#33',
#  'install/dress/test production fiber (includes mor rack set & fiber runner)': 'Cluster#48',
#  'msft delivery -ofci submittal release': 'Cluster#33',
#  'msft - soft release on unapproved urs submittal': 'Cluster#33',
#  'set gen stack / exhaust duct': 'Cluster#33',
#  'install roxtec block sealing and install added tray cable (drb#3)': 'Cluster#33',
#  'set exterior water treatment equipment': 'Cluster#33',
#  'set exterior water treatment facilities': 'Cluster#33',
#  'change order release for fluid cooler wiring devices': 'Cluster#33',
#  'security system complete': 'Cluster#33',
#  'se directs veca to start flex conduit fixes': 'Cluster#33',
#  'se directs veca to start roxtec fixes': 'Cluster#33',
#  'se directs veca to start roxtec fixes(delete)': 'Cluster#33',
#  'awaiting phase conductor lugs from nc power as per rfi#412': 'Cluster#33',
#  '6.1.40- 480v house power to gen enclousure is fed oh vs ug': 'Cluster#33',
#  '6.1.57 -awaiting revised coordination study #9': 'Cluster#33',
#  'reprint revised panel 3,4 arc flash labels': 'Cluster#33',
#  'complete  beneficial use - facilities operations centre (foc) ': 'Cluster#33',
#  'complete beneficial use - facility cable room (fcr)': 'Cluster#33',
#  'complete beneficial use - meet me rooms or entry rooms (mmr/er)': 'Cluster#33',
#  'complete beneficial use - security equipment room (ser)': 'Cluster#33',
#  'complete beneficial use': 'Cluster#33',
#  'complete beneficial use - regional network gateway (rng) ': 'Cluster#33',
#  'complete beneficial use - secure storage': 'Cluster#33',
#  'complete security system': 'Cluster#33',
#  'complete  beneficial use - facilities operations centre (foc)': 'Cluster#33',
#  'se': 'Cluster#33',
#  'perimeter foundations - excavate/frp': 'Cluster#34',
#  'perimeter foundations - excavate/frp/backfill': 'Cluster#34',
#  'perimeter foundations - waterproof backfill': 'Cluster#35',
#  'perimeter foundations - waterproof/backfill': 'Cluster#35',
#  'foundations': 'Cluster#34',
#  'roof panels installation': 'Cluster#35',
#  'roof panel start -colo 2': 'Cluster#35',
#  'roof panel start -colo 3': 'Cluster#35',
#  'roof panel start - colo 4': 'Cluster#35',
#  'lead time for wall & roof metal panels': 'Cluster#35',
#  'roof': 'Cluster#35',
#  'hang wall partitions- early walls': 'Cluster#36',
#  'hang wall partitions': 'Cluster#36',
#  'partitions': 'Cluster#36',
#  'early room - finishes': 'Cluster#37',
#  'datahall finishes- ceiling grid': 'Cluster#37',
#  'mechanical corridor finishes': 'Cluster#41',
#  'datahall finishes - ceiling grid': 'Cluster#37',
#  'datahall finishes': 'Cluster#37',
#  'interior finishes/csa complete': 'Cluster#37',
#  'complete interior finishes/csa': 'Cluster#37',
#  'finishes': 'Cluster#37',
#  'landscaping & specialities': 'Cluster#38',
#  'specialities': 'Cluster#38',
#  'other electrical equipment': 'Cluster#39',
#  'electrical devices & trim': 'Cluster#39',
#  'electrical equipment yellow tagging': 'Cluster#39',
#  'exterior equipment pads - electrical': 'Cluster#39',
#  'electrical underground rough-in': 'Cluster#39',
#  'ofci lvl 3 testing & start up (electrical equipment)': 'Cluster#39',
#  'design / lead time for electrical/telecom (ofci telecom bom materials)': 'Cluster#39',
#  'completion of utility/mv ug electrical': 'Cluster#39',
#  'electrical oh below mechanical piping': 'Cluster#41',
#  'ats- lvl 3 testing & start up (electrical equipment)': 'Cluster#39',
#  'electrical': 'Cluster#39',
#  'plumbing devices & trim': 'Cluster#40',
#  'mechanical/plumbing underground rough-in': 'Cluster#41',
#  'plumbing': 'Cluster#40',
#  'cell 1 mechanical corridor': 'Cluster#41',
#  'cell 3 mechanical corridor': 'Cluster#41',
#  'cell 2 mechanical corridor': 'Cluster#41',
#  'cell 4 mechanical corridor': 'Cluster#41',
#  'mechanical corridor cell  1': 'Cluster#41',
#  'mechanical corridor cell  3': 'Cluster#41',
#  'mechanical corridor cell  2': 'Cluster#41',
#  'mechanical corridor cell  4': 'Cluster#41',
#  'mechanical passageway cell  4': 'Cluster#41',
#  'cell 2  mechanical passageway': 'Cluster#41',
#  'cell 4 mechanical passageway': 'Cluster#41',
#  'cell 2 mechanical passageway': 'Cluster#41',
#  'cell d4 mechanical passageway': 'Cluster#41',
#  'mechanical ductwork installation': 'Cluster#41',
#  'mechanical devices & trim': 'Cluster#41',
#  'exterior equipment pads - mechanical': 'Cluster#41',
#  'steel supports for exterior mechanical equipment (fluid cooler steel & pipe steel supports)': 'Cluster#41',
#  ...}

# %%
data["cluster"] = data['lower_case_names'].map(map_cluster_to_cluster_name(name_clusters))
# Out:
# 55

# %%
## proper mapping

def map_cluster_name(lower_case_name):
    mapping = map_cluster_to_cluster_name(name_clusters)
    if lower_case_name in mapping:
        return mapping[lower_case_name]
    else:
        return np.nan

# %%
data["cluster"] = data['lower_case_names'].map(map_cluster_name)
# Out:
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55

# %%
data.head()
# Out:
#           id   activity_id                                           name  \
# 0  3,191,380    MDC1-UP#13  MDC1 Master Update #13- DD 8.31.2021Submitted
# 1  3,191,381  MDC1-UP#13.1                 Executive Summary / Milestones
# 2  3,192,817  MDC1-UP#13.5                                   Construction
# 3  3,191,388  MDC1-UP#13.2                           Construction Summary
# 4  3,191,673  MDC1-UP#13.4                                Preconstruction
#
#                                 lower_case_names  is_one_word_name    cluster
# 0  mdc1 master update #13- dd 8.31.2021submitted             False        NaN
# 1                 executive summary / milestones             False        NaN
# 2                                   construction              True  Cluster#1
# 3                           construction summary             False  Cluster#1
# 4                                preconstruction              True  Cluster#2

# %%
data.tail(60)
# Out:
#              id       activity_id  \
# 3376  3,192,751        MDC1-10554
# 3377  3,192,752        MDC1-10555
# 3378  3,192,753        MDC1-10556
# 3379  3,192,758        MDC1-10557
# 3380  3,192,759        MDC1-10558
# 3381  3,192,760        MDC1-10560
# 3382  3,192,761        MDC1-10561
# 3383  3,192,762        MDC1-10562
# 3384  3,192,763        MDC1-10563
# 3385  3,192,764        MDC1-10564
# 3386  3,192,765        MDC1-10565
# 3387  3,192,766        MDC1-10566
# 3388  3,192,767        MDC1-10567
# 3389  3,192,768        MDC1-10568
# 3390  3,192,769        MDC1-10569
# 3391  3,192,770        MDC1-10570
# 3392  3,192,771        MDC1-10571
# 3393  3,192,540        MDC1-10572
# 3394  3,194,542        MDC1-10573
# 3395  3,192,541        MDC1-10574
# 3396  3,192,774        MDC1-10575
# 3397  3,192,776        MDC1-10576
# 3398  3,192,777        MDC1-10577
# 3399  3,192,778        MDC1-10578
# 3400  3,192,779        MDC1-10579
# 3401  3,192,542        MDC1-10580
# 3402  3,192,783        MDC1-10581
# 3403  3,192,784        MDC1-10582
# 3404  3,192,785        MDC1-10583
# 3405  3,192,786        MDC1-10584
# 3406  3,192,792        MDC1-10585
# 3407  3,194,331        MDC1-10586
# 3408  3,192,794        MDC1-10587
# 3409  3,192,788        MDC1-10588
# 3410  3,192,789        MDC1-10589
# 3411  3,192,790        MDC1-10590
# 3412  3,194,543        MDC1-10592
# 3413  3,194,544        MDC1-10593
# 3414  3,194,545        MDC1-10594
# 3415  3,194,546        MDC1-10595
# 3416  3,194,547        MDC1-10596
# 3417  3,194,548        MDC1-10597
# 3418  3,194,549        MDC1-10598
# 3419  3,194,550        MDC1-10599
# 3420  3,194,551        MDC1-10600
# 3421  3,194,552        MDC1-10601
# 3422  3,194,553        MDC1-10602
# 3423  3,192,799        MDC1-10603
# 3424  3,192,800        MDC1-10604
# 3425  3,192,801        MDC1-10605
# 3426  3,192,802        MDC1-10606
# 3427  3,194,335  MDC1.C1.Cx3020.1
# 3428  3,192,808        MDC1-10607
# 3429  3,192,809        MDC1-10608
# 3430  3,192,810        MDC1-10609
# 3431  3,192,812        MDC1-10610
# 3432  3,192,818        MDC1-10611
# 3433  3,192,813        MDC1-10612
# 3434  3,192,814        MDC1-10613
# 3435  3,192,816        MDC1-10614
#
#                                                    name  \
# 3376  COLO-4 Cell-2 MER-UPS Battery Disconnect modif...
# 3377  COLO-4 Cell-3 MER-UPS Battery Disconnect modif...
# 3378  COLO-4 Cell-4 MER-UPS Battery Disconnect modif...
# 3379      COLO-3 Cell-4 Remove inaccessible tray in MER
# 3380                COLO-3 Cell-4 Reinstall tray in MER
# 3381      COLO-4 Cell-1 Remove inaccessible tray in MER
# 3382                COLO-4 Cell-1 Reinstall tray in MER
# 3383      COLO-4 Cell-2 Remove inaccessible tray in MER
# 3384                COLO-4 Cell-2 Reinstall tray in MER
# 3385      COLO-4 Cell-3 Remove inaccessible tray in MER
# 3386                COLO-4 Cell-3 Reinstall tray in MER
# 3387     COLO-4 Cell-4 Remove inaccessible tray in MER4
# 3388                COLO-4 Cell-4 Reinstall tray in MER
# 3389      COLO-3 Cell-1 Remove inaccessible tray in MER
# 3390                COLO-3 CEll-1 Reinstall tray in MER
# 3391      COLO-3 Cell-2 Remove inaccessible tray in MER
# 3392                COLO-3 Cell-2 Reinstall tray in MER
# 3393  #4. Extreme Heat - 6/28/21- 7/2/21(Effecting C...
# 3394                             CSA Punchlist - COLO-1
# 3395  #5 Extreme heat -production loss in Yards 7/1/...
# 3396                       COLO-3 Cell-3 Conduit rework
# 3397                       COLO-4 Cell-1 Conduit rework
# 3398                       COLO-4 Cell-2 Conduit rework
# 3399                       COLO-4 Cell-3 Conduit rework
# 3400                       COLO-4 Cell-4 Conduit rework
# 3401  #6 Extreme heat - Production loss in Yards 7/1...
# 3402  6.1-88 COLO-1 MER awaiting updated UPS L3 test...
# 3403  6.1-89 RFI574- COLO-1 Relocating MSB EPMS devi...
# 3404  6.1-92 COLO-1 SF/ RF startup delay (vendor sch...
# 3405  6.1-93 COLO-1 HVAC minisplits startup delay (v...
# 3406  6.1-95 COLO-1 ATS's L3 startup delay (vendor s...
# 3407  ATS- Lvl 3 Testing & Start up (Electrical Equi...
# 3408  6.1-96 COLO-1 PDU - EPMS L3 startup delay (ven...
# 3409  6.2-08 COLO-2 Cell- 1,2 MER equipment Phenolic...
# 3410  6.2-08 COLO-2 Cell- 3,4 MER equipment Phenolic...
# 3411  6.2-12 COLO-2 All Cells- Factory connection To...
# 3412                             CSA Punchlist - COLO-2
# 3413                             CSA Punchlist - COLO-3
# 3414                             CSA Punchlist - COLO-4
# 3415                             MEP Punchlist - COLO-1
# 3416                             MEP Punchlist - COLO-2
# 3417                             MEP Punchlist - COLO-3
# 3418                             MEP Punchlist - COLO-4
# 3419                        AE/Owner Punchlist - COLO-1
# 3420                        AE/Owner Punchlist - COLO-2
# 3421                        AE/Owner Punchlist - COLO-3
# 3422                        AE/Owner Punchlist - COLO-4
# 3423  COLO-2 Cell-1 UPS PNL01 Compass issues Prevent...
# 3424  COLO-2 Cell-2 UPS PNL01 Compass issues Prevent...
# 3425  COLO-2 Cell-3 UPS PNL01 Compass issues Prevent...
# 3426  COLO-2 Cell-4 UPS PNL01 Compass issues Prevent...
# 3427              Additional Go-Back loadbanking (ASCO)
# 3428  6.1-98 Admin/COLO-1 ASCO EPMS Connectivity Issues
# 3429  6.1-88  Admin/ COLO-1 MER/ADMIN UPS L3 Testing...
# 3430   6.1-106 COLO-1 Cell-2 UPS01 Power module failure
# 3431  COLO-2 Cell-1 Open Issues preventing Yellow ta...
# 3432  COLO-2 Cell-2 Open Issues preventing Yellow ta...
# 3433  COLO-2 Cell-3 Open Issues preventing Yellow ta...
# 3434  COLO-2 Cell-4 Open Issues preventing Yellow ta...
# 3435          COLO-3 Delay in SE uploading QC Checkilst
#
#                                        lower_case_names  is_one_word_name  \
# 3376  colo-4 cell-2 mer-ups battery disconnect modif...             False
# 3377  colo-4 cell-3 mer-ups battery disconnect modif...             False
# 3378  colo-4 cell-4 mer-ups battery disconnect modif...             False
# 3379      colo-3 cell-4 remove inaccessible tray in mer             False
# 3380                colo-3 cell-4 reinstall tray in mer             False
# 3381      colo-4 cell-1 remove inaccessible tray in mer             False
# 3382                colo-4 cell-1 reinstall tray in mer             False
# 3383      colo-4 cell-2 remove inaccessible tray in mer             False
# 3384                colo-4 cell-2 reinstall tray in mer             False
# 3385      colo-4 cell-3 remove inaccessible tray in mer             False
# 3386                colo-4 cell-3 reinstall tray in mer             False
# 3387     colo-4 cell-4 remove inaccessible tray in mer4             False
# 3388                colo-4 cell-4 reinstall tray in mer             False
# 3389      colo-3 cell-1 remove inaccessible tray in mer             False
# 3390                colo-3 cell-1 reinstall tray in mer             False
# 3391      colo-3 cell-2 remove inaccessible tray in mer             False
# 3392                colo-3 cell-2 reinstall tray in mer             False
# 3393  #4. extreme heat - 6/28/21- 7/2/21(effecting c...             False
# 3394                             csa punchlist - colo-1             False
# 3395  #5 extreme heat -production loss in yards 7/1/...             False
# 3396                       colo-3 cell-3 conduit rework             False
# 3397                       colo-4 cell-1 conduit rework             False
# 3398                       colo-4 cell-2 conduit rework             False
# 3399                       colo-4 cell-3 conduit rework             False
# 3400                       colo-4 cell-4 conduit rework             False
# 3401  #6 extreme heat - production loss in yards 7/1...             False
# 3402  6.1-88 colo-1 mer awaiting updated ups l3 test...             False
# 3403  6.1-89 rfi574- colo-1 relocating msb epms devi...             False
# 3404  6.1-92 colo-1 sf/ rf startup delay (vendor sch...             False
# 3405  6.1-93 colo-1 hvac minisplits startup delay (v...             False
# 3406  6.1-95 colo-1 ats's l3 startup delay (vendor s...             False
# 3407  ats- lvl 3 testing & start up (electrical equi...             False
# 3408  6.1-96 colo-1 pdu - epms l3 startup delay (ven...             False
# 3409  6.2-08 colo-2 cell- 1,2 mer equipment phenolic...             False
# 3410  6.2-08 colo-2 cell- 3,4 mer equipment phenolic...             False
# 3411  6.2-12 colo-2 all cells- factory connection to...             False
# 3412                             csa punchlist - colo-2             False
# 3413                             csa punchlist - colo-3             False
# 3414                             csa punchlist - colo-4             False
# 3415                             mep punchlist - colo-1             False
# 3416                             mep punchlist - colo-2             False
# 3417                             mep punchlist - colo-3             False
# 3418                             mep punchlist - colo-4             False
# 3419                        ae/owner punchlist - colo-1             False
# 3420                        ae/owner punchlist - colo-2             False
# 3421                        ae/owner punchlist - colo-3             False
# 3422                        ae/owner punchlist - colo-4             False
# 3423  colo-2 cell-1 ups pnl01 compass issues prevent...             False
# 3424  colo-2 cell-2 ups pnl01 compass issues prevent...             False
# 3425  colo-2 cell-3 ups pnl01 compass issues prevent...             False
# 3426  colo-2 cell-4 ups pnl01 compass issues prevent...             False
# 3427              additional go-back loadbanking (asco)             False
# 3428  6.1-98 admin/colo-1 asco epms connectivity issues             False
# 3429  6.1-88  admin/ colo-1 mer/admin ups l3 testing...             False
# 3430   6.1-106 colo-1 cell-2 ups01 power module failure             False
# 3431  colo-2 cell-1 open issues preventing yellow ta...             False
# 3432  colo-2 cell-2 open issues preventing yellow ta...             False
# 3433  colo-2 cell-3 open issues preventing yellow ta...             False
# 3434  colo-2 cell-4 open issues preventing yellow ta...             False
# 3435          colo-3 delay in se uploading qc checkilst             False
#
#          cluster
# 3376  Cluster#45
# 3377  Cluster#44
# 3378  Cluster#46
# 3379  Cluster#46
# 3380  Cluster#46
# 3381  Cluster#43
# 3382  Cluster#43
# 3383  Cluster#45
# 3384  Cluster#45
# 3385  Cluster#44
# 3386  Cluster#44
# 3387  Cluster#46
# 3388  Cluster#46
# 3389  Cluster#43
# 3390  Cluster#43
# 3391  Cluster#45
# 3392  Cluster#45
# 3393  Cluster#11
# 3394  Cluster#20
# 3395         NaN
# 3396  Cluster#44
# 3397  Cluster#43
# 3398  Cluster#45
# 3399  Cluster#44
# 3400  Cluster#46
# 3401         NaN
# 3402  Cluster#25
# 3403  Cluster#20
# 3404  Cluster#20
# 3405  Cluster#20
# 3406  Cluster#24
# 3407  Cluster#39
# 3408  Cluster#31
# 3409  Cluster#25
# 3410  Cluster#25
# 3411   Cluster#9
# 3412  Cluster#13
# 3413  Cluster#13
# 3414  Cluster#13
# 3415  Cluster#20
# 3416  Cluster#13
# 3417  Cluster#13
# 3418  Cluster#13
# 3419  Cluster#20
# 3420  Cluster#13
# 3421  Cluster#13
# 3422  Cluster#13
# 3423  Cluster#43
# 3424  Cluster#45
# 3425  Cluster#44
# 3426  Cluster#46
# 3427         NaN
# 3428  Cluster#21
# 3429  Cluster#25
# 3430  Cluster#45
# 3431  Cluster#43
# 3432  Cluster#45
# 3433  Cluster#44
# 3434  Cluster#46
# 3435  Cluster#33

# %%
data.head()
# Out:
#           id   activity_id                                           name  \
# 0  3,191,380    MDC1-UP#13  MDC1 Master Update #13- DD 8.31.2021Submitted
# 1  3,191,381  MDC1-UP#13.1                 Executive Summary / Milestones
# 2  3,192,817  MDC1-UP#13.5                                   Construction
# 3  3,191,388  MDC1-UP#13.2                           Construction Summary
# 4  3,191,673  MDC1-UP#13.4                                Preconstruction
#
#                                 lower_case_names  is_one_word_name    cluster
# 0  mdc1 master update #13- dd 8.31.2021submitted             False        NaN
# 1                 executive summary / milestones             False        NaN
# 2                                   construction              True  Cluster#1
# 3                           construction summary             False  Cluster#1
# 4                                preconstruction              True  Cluster#2

# %%
data.cluster.isna().count()
# Out:
# 3436

# %%
3436 - 55
# Out:
# 3381

# %%
data.to_csv("naive_clusters.csv")
